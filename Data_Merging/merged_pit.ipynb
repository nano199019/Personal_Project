# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
pit_df = pd.read_csv('./[ST]Personal_Project/dataset/mlb_fa_pit_list2.csv')
test_pit = pd.read_csv('./[ST]Personal_Project/dataset/fa_2018_pit_list.csv')

# %%
pit_df.shape, test_pit.shape
# Out:
# ((589, 41), (26, 41))

# %%
pit_df.tail()
# Out:
#                Name    Yr     Team  W  L   G  GS  CG    IP   H  HR  BB  SO  \
# 584     Sergio Romo  2016   Giants  1  0  40   0   0  30.2  26   5   7  33
# 585  Shawn Tolleson  2016  Rangers  2  2  37   0   0  36.1  53   8  10  29
# 586     Travis Wood  2016     Cubs  4  0  77   0   0  61.0  45   8  24  47
# 587   Trevor Cahill  2016     Cubs  4  4  50   1   0  65.2  49   7  35  66
# 588      Tyson Ross  2016   Padres  0  1   1   1   0   5.1   9   0   1   5
#
#       R  SV  BS  BK  ER  HBP  HLD  IBB  ShO  TBF  WP  HR/9  BB/9   K/9  K/BB  \
# 584   9   4   0   0   9    0   14    1    0  117   1  1.47  2.05  9.68  4.71
# 585  32  11   4   0  31    0    1    2    0  168   1  1.98  2.48  7.18  2.90
# 586  24   0   1   0  20    1   12    2    0  252   0  1.18  3.54  6.93  1.96
# 587  22   0   1   0  20    5    4    3    0  284   3  0.96  4.80  9.05  1.89
# 588   8   0   0   0   7    2    0    0    0   27   1  0.00  1.69  8.44  5.00
#
# ...

# %%
test_pit.head()
# Out:
#                Name    Yr       Team  W  L   G  GS  CG    IP   H  HR  BB  SO  \
# 0   Anthony Swarzak  2017    Brewers  6  4  70   0   0  77.1  58   6  22  91
# 1       Boone Logan  2017    Indians  1  0  38   0   0  21.0  20   2   9  28
# 2  Brandon Kintzler  2017  Nationals  4  3  72   0   0  71.1  66   5  16  39
# 3    Brandon Morrow  2017    Dodgers  6  0  45   0   0  43.2  31   0   9  50
# 4        Bryan Shaw  2017    Indians  4  6  79   0   0  76.2  71   5  22  73
#
#     R  SV  BS  BK  ER  HBP  HLD  IBB  ShO  TBF  WP  HR/9  BB/9    K/9  K/BB  \
# 0  21   2   3   0  20    2   27    4    0  303   2  0.70  2.56  10.59  4.14
# 1  13   0   1   0  11    1    4    0    0   91   0  0.86  3.86  12.00  3.11
# 2  25  29   6   0  24    3   10    2    0  288   1  0.63  2.02   4.92  2.44
# 3  10   2   1   0  10    1   10    1    0  170   2  0.00  1.85  10.31  5.56
# 4  36   3   3   0  30    0   26    3    0  312   3  0.59  2.58   8.57  3.32
#
# ...

# %%
test_pit = test_pit.rename(columns={'Contract_Yrs' : 'Contract Yrs', 'Total_Salary' : 'Total Salary($)',
                                    'Salary' : 'Avg Salary($)'})

# %%
print(pit_df.columns.tolist())
# Out:
# ['Name', 'Yr', 'Team', 'W', 'L', 'G', 'GS', 'CG', 'IP', 'H', 'HR', 'BB', 'SO', 'R', 'SV', 'BS', 'BK', 'ER', 'HBP', 'HLD', 'IBB', 'ShO', 'TBF', 'WP', 'HR/9', 'BB/9', 'K/9', 'K/BB', 'K-BB%', 'GB%', 'HR/FB', 'LOB%', 'ERA', 'BABIP', 'FIP', 'WHIP', 'WPA', 'WAR', 'Contract Yrs', 'Total Salary($)', 'Avg Salary($)']

# %%
merged_pit = pd.concat([pit_df, test_pit])

merge_1 = merged_pit.set_index('Name', inplace=False)
merge_2 = merge_1.reset_index()

merged_pit = merge_2

# %%
print(merged_pit.columns.tolist())
# Out:
# ['Name', 'Yr', 'Team', 'W', 'L', 'G', 'GS', 'CG', 'IP', 'H', 'HR', 'BB', 'SO', 'R', 'SV', 'BS', 'BK', 'ER', 'HBP', 'HLD', 'IBB', 'ShO', 'TBF', 'WP', 'HR/9', 'BB/9', 'K/9', 'K/BB', 'K-BB%', 'GB%', 'HR/FB', 'LOB%', 'ERA', 'BABIP', 'FIP', 'WHIP', 'WPA', 'WAR', 'Contract Yrs', 'Total Salary($)', 'Avg Salary($)']

# %%
merged_pit.tail(30)
# Out:
#                  Name    Yr          Team   W   L   G  GS  CG     IP    H  HR  \
# 585    Shawn Tolleson  2016       Rangers   2   2  37   0   0   36.1   53   8
# 586       Travis Wood  2016          Cubs   4   0  77   0   0   61.0   45   8
# 587     Trevor Cahill  2016          Cubs   4   4  50   1   0   65.2   49   7
# 588        Tyson Ross  2016        Padres   0   1   1   1   0    5.1    9   0
# 589   Anthony Swarzak  2017       Brewers   6   4  70   0   0   77.1   58   6
# 590       Boone Logan  2017       Indians   1   0  38   0   0   21.0   20   2
# 591  Brandon Kintzler  2017     Nationals   4   3  72   0   0   71.1   66   5
# 592    Brandon Morrow  2017       Dodgers   6   0  45   0   0   43.2   31   0
# 593        Bryan Shaw  2017       Indians   4   6  79   0   0   76.2   71   5
# 594     Craig Stammen  2017        Padres   2   3  60   0   0   80.1   68  12
# 595       Doug Fister  2017       Red Sox   5   9  18  15   1   90.1   87   9
# ...

# %%
merged_pit.to_csv('./[ST]Personal_Project/dataset/merged_pit.csv', index=None)
