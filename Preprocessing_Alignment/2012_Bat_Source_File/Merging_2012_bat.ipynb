# %%
import pandas as pd
import numpy as np
import re

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
read_dash = pd.read_csv('../csv/2012/Merging_2012_DASH_bat.csv')
read_std = pd.read_csv('../csv/2012/Merging_2012_STD_bat.csv')
read_adv = pd.read_csv('../csv/2012/Merging_2012_ADV_bat.csv')
read_wpa = pd.read_csv('../csv/2012/Merging_2012_WPA_bat.csv')

# %%
rd = read_dash.copy()
rs = read_std.copy()
ra = read_adv.copy()
rw = read_wpa.copy()

# %%
merge1 = rd.merge(rs, how='inner')
merge2 = merge1.merge(ra, how='inner')
merge = merge2.merge(rw, how='inner')

# %%
to_list = merge.columns.tolist()

to_list = ['Name', 'Team', 'G', 'AB', 'PA', 'H', '1B', '2B', '3B', 'HR', 'R', 'RBI', 'BB', 'IBB', 'SO', 'BB%', 'K%', 'BB/K', 'BABIP', 'HBP', 'SF', 'SH', 'GDP', 'SB', 'CS', 'Def', 'ISO', 'wOBA', 'wRAA', 'AVG', 'OBP', 'SLG', 'OPS', 'WAR', 'wRC+', 'WPA']
merge = merge[to_list]

print(merge.shape)
# Out:
# (143, 36)

# %%
copy = merge.copy()

# %%
bb_list = list(copy['BB%'])
k_list = list(copy['K%'])

bb = [float(re.sub(r' %', '', x)) for x in list(bb_list)]
k = [float(re.sub(r' %', '', x)) for x in list(k_list)]

# %%
merge['BB%'] = bb
merge['K%'] = k

# %%
print(merge.shape)
merge
# Out:
# (143, 36)
#                   Name          Team    G   AB   PA    H   1B  2B  3B  HR  \
# 0           Mike Trout        Angels  139  559  639  182  117  27   8  30
# 1         Buster Posey        Giants  148  530  610  178  114  39   1  24
# 2        Robinson Cano       Yankees  161  627  697  196  114  48   1  33
# 3        Chase Headley        Padres  161  604  699  173  109  31   2  31
# 4         David Wright          Mets  156  581  670  178  114  41   2  21
# 5           Ryan Braun       Brewers  154  598  677  191  111  36   3  41
# 6     Andrew McCutchen       Pirates  157  593  673  194  128  29   6  31
# 7        Adrian Beltre       Rangers  156  604  654  194  123  33   2  36
# 8        Jason Heyward        Braves  158  587  651  158   95  30   6  27
# 9       Miguel Cabrera        Tigers  161  622  697  205  121  40   0  44
# 10       Michael Bourn        Braves  155  624  703  171  126  26  10   9
# ...

# %%
merge.loc[44, 'Team'] = 'Dodgers'
merge.loc[60, 'Team'] = 'Red Sox'
merge.loc[62, 'Team'] = 'Minor'
merge.loc[77, 'Team'] = 'Dodgers'
merge.loc[78, 'Team'] = 'Yankees'
merge.loc[102, 'Team'] = 'Giants'
merge.loc[107, 'Team'] = 'Giants'
merge.loc[120, 'Team'] = 'White Sox'
merge.loc[121, 'Team'] = 'Diamondback'
merge.loc[132, 'Team'] = 'Marlins'

# %%
print(merge.shape)
merge
# Out:
# (143, 36)
#                   Name          Team    G   AB   PA    H   1B  2B  3B  HR  \
# 0           Mike Trout        Angels  139  559  639  182  117  27   8  30
# 1         Buster Posey        Giants  148  530  610  178  114  39   1  24
# 2        Robinson Cano       Yankees  161  627  697  196  114  48   1  33
# 3        Chase Headley        Padres  161  604  699  173  109  31   2  31
# 4         David Wright          Mets  156  581  670  178  114  41   2  21
# 5           Ryan Braun       Brewers  154  598  677  191  111  36   3  41
# 6     Andrew McCutchen       Pirates  157  593  673  194  128  29   6  31
# 7        Adrian Beltre       Rangers  156  604  654  194  123  33   2  36
# 8        Jason Heyward        Braves  158  587  651  158   95  30   6  27
# 9       Miguel Cabrera        Tigers  161  622  697  205  121  40   0  44
# 10       Michael Bourn        Braves  155  624  703  171  126  26  10   9
# ...

# %%
merge.dtypes
# Out:
# Name      object
# Team      object
# G          int64
# AB         int64
# PA         int64
# H          int64
# 1B         int64
# 2B         int64
# 3B         int64
# HR         int64
# R          int64
# RBI        int64
# BB         int64
# IBB        int64
# SO         int64
# BB%      float64
# K%       float64
# BB/K     float64
# BABIP    float64
# HBP        int64
# SF         int64
# SH         int64
# GDP        int64
# SB         int64
# CS         int64
# Def      float64
# ISO      float64
# wOBA     float64
# wRAA     float64
# AVG      float64
# OBP      float64
# SLG      float64
# OPS      float64
# WAR      float64
# wRC+       int64
# WPA      float64
# dtype: object

# %%
merge.to_csv('../csv/2012/2012_Merging_batters_stats.csv', index=None)
