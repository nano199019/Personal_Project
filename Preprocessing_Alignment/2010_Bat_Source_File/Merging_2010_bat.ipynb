# %%
import pandas as pd
import numpy as np
import re

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
read_dash = pd.read_csv('../csv/2010/Merging_2010_DASH_bat.csv')
read_std = pd.read_csv('../csv/2010/Merging_2010_STD_bat.csv')
read_adv = pd.read_csv('../csv/2010/Merging_2010_ADV_bat.csv')
read_wpa = pd.read_csv('../csv/2010/Merging_2010_WPA_bat.csv')

# %%
rd = read_dash.copy()
rs = read_std.copy()
ra = read_adv.copy()
rw = read_wpa.copy()

# %%
merge1 = rd.merge(rs, how='inner')
merge2 = merge1.merge(ra, how='inner')
merge = merge2.merge(rw, how='inner')

# %%
to_list = merge.columns.tolist()

to_list = ['Name', 'Team', 'G', 'AB', 'PA', 'H', '1B', '2B', '3B', 'HR', 'R', 'RBI', 'BB', 'IBB', 'SO', 'BB%', 'K%', 'BB/K', 'BABIP', 'HBP', 'SF', 'SH', 'GDP', 'SB', 'CS', 'Def', 'ISO', 'wOBA', 'wRAA', 'AVG', 'OBP', 'SLG', 'OPS', 'WAR', 'wRC+', 'WPA']
merge = merge[to_list]

print(merge.shape)
# Out:
# (149, 36)

# %%
copy = merge.copy()

# %%
bb_list = list(copy['BB%'])
k_list = list(copy['K%'])

bb = [float(re.sub(r' %', '', x)) for x in list(bb_list)]
k = [float(re.sub(r' %', '', x)) for x in list(k_list)]

# %%
merge['BB%'] = bb
merge['K%'] = k

# %%
print(merge.shape)
merge
# Out:
# (149, 36)
#                     Name          Team    G   AB   PA    H   1B  2B  3B  HR  \
# 0          Josh Hamilton       Rangers  133  518  571  186  111  40   3  32
# 1          Carl Crawford          Rays  154  600  663  184  122  30  13  19
# 2          Evan Longoria          Rays  151  574  661  169   96  46   5  22
# 3             Joey Votto          Reds  150  547  648  177  102  36   2  37
# 4          Albert Pujols     Cardinals  159  587  700  183  101  39   1  42
# 5         Ryan Zimmerman     Nationals  142  525  603  161  104  32   0  25
# 6          Jose Bautista     Blue Jays  161  569  683  148   56  35   3  54
# 7          Adrian Beltre       Red Sox  154  589  641  189  110  49   2  28
# 8          Robinson Cano       Yankees  160  626  696  200  127  41   3  29
# 9          Andres Torres        Giants  139  507  570  136   69  43   8  16
# 10         Matt Holliday     Cardinals  158  596  675  186  112  45   1  28
# ...

# %%
merge.loc[63, 'Team'] = 'Braves'
merge.loc[88, 'Team'] = 'Giants'
merge.loc[97, 'Team'] = 'Blue Jays'
merge.loc[101, 'Team'] = 'Padres'
merge.loc[103, 'Team'] = 'Braves'
merge.loc[107, 'Team'] = 'Indians'
merge.loc[122, 'Team'] = 'Angels'
merge.loc[123, 'Team'] = 'Orioles'
merge.loc[130, 'Team'] = 'Dodgers'
merge.loc[132, 'Team'] = 'Rangers'
merge.loc[133, 'Team'] = 'Royals'
merge.loc[142, 'Team'] = 'Rangers'
merge.loc[143, 'Team'] = 'Dodgers'

# %%
print(merge.shape)
merge
# Out:
# (149, 36)
#                     Name          Team    G   AB   PA    H   1B  2B  3B  HR  \
# 0          Josh Hamilton       Rangers  133  518  571  186  111  40   3  32
# 1          Carl Crawford          Rays  154  600  663  184  122  30  13  19
# 2          Evan Longoria          Rays  151  574  661  169   96  46   5  22
# 3             Joey Votto          Reds  150  547  648  177  102  36   2  37
# 4          Albert Pujols     Cardinals  159  587  700  183  101  39   1  42
# 5         Ryan Zimmerman     Nationals  142  525  603  161  104  32   0  25
# 6          Jose Bautista     Blue Jays  161  569  683  148   56  35   3  54
# 7          Adrian Beltre       Red Sox  154  589  641  189  110  49   2  28
# 8          Robinson Cano       Yankees  160  626  696  200  127  41   3  29
# 9          Andres Torres        Giants  139  507  570  136   69  43   8  16
# 10         Matt Holliday     Cardinals  158  596  675  186  112  45   1  28
# ...

# %%
merge.dtypes
# Out:
# Name      object
# Team      object
# G          int64
# AB         int64
# PA         int64
# H          int64
# 1B         int64
# 2B         int64
# 3B         int64
# HR         int64
# R          int64
# RBI        int64
# BB         int64
# IBB        int64
# SO         int64
# BB%      float64
# K%       float64
# BB/K     float64
# BABIP    float64
# HBP        int64
# SF         int64
# SH         int64
# GDP        int64
# SB         int64
# CS         int64
# Def      float64
# ISO      float64
# wOBA     float64
# wRAA     float64
# AVG      float64
# OBP      float64
# SLG      float64
# OPS      float64
# WAR      float64
# wRC+       int64
# WPA      float64
# dtype: object

# %%
merge.to_csv('../csv/2010/2010_Merging_batters_stats.csv', index=None)
