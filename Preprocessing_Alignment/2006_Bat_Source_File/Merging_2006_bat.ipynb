# %%
import pandas as pd
import numpy as np
import re

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
read_dash = pd.read_csv('../csv/2006/Merging_2006_DASH_bat.csv')
read_std = pd.read_csv('../csv/2006/Merging_2006_STD_bat.csv')
read_adv = pd.read_csv('../csv/2006/Merging_2006_ADV_bat.csv')
read_wpa = pd.read_csv('../csv/2006/Merging_2006_WPA_bat.csv')

# %%
rd = read_dash.copy()
rs = read_std.copy()
ra = read_adv.copy()
rw = read_wpa.copy()

# %%
merge1 = rd.merge(rs, how='inner')
merge2 = merge1.merge(ra, how='inner')
merge = merge2.merge(rw, how='inner')

# %%
to_list = merge.columns.tolist()

to_list = ['Name', 'Team', 'G', 'AB', 'PA', 'H', '1B', '2B', '3B', 'HR', 'R', 'RBI', 'BB', 'IBB', 'SO', 'BB%', 'K%', 'BB/K', 'BABIP', 'HBP', 'SF', 'SH', 'GDP', 'SB', 'CS', 'Def', 'ISO', 'wOBA', 'wRAA', 'AVG', 'OBP', 'SLG', 'OPS', 'WAR', 'wRC+', 'WPA']
merge = merge[to_list]

print(merge.shape)
# Out:
# (160, 36)

# %%
copy = merge.copy()

# %%
bb_list = list(copy['BB%'])
k_list = list(copy['K%'])

bb = [float(re.sub(r' %', '', x)) for x in list(bb_list)]
k = [float(re.sub(r' %', '', x)) for x in list(k_list)]

# %%
merge['BB%'] = bb
merge['K%'] = k

# %%
print(merge.shape)
merge
# Out:
# (160, 36)
#                     Name          Team    G   AB   PA    H   1B  2B  3B  HR  \
# 0          Albert Pujols     Cardinals  143  535  634  177   94  33   1  49
# 1         Grady Sizemore       Indians  162  655  751  190   98  53  11  28
# 2         Carlos Beltran          Mets  140  510  617  140   60  38   1  41
# 3            Chase Utley      Phillies  160  658  739  203  127  40   4  32
# 4         Miguel Cabrera       Marlins  158  576  676  195  117  50   2  26
# 5            Derek Jeter       Yankees  154  623  715  214  158  39   3  14
# 6          Lance Berkman        Astros  152  536  646  169   95  29   0  45
# 7           Andruw Jones        Braves  156  565  669  148   78  29   0  41
# 8          Travis Hafner       Indians  129  454  564  140   66  31   1  42
# 9            Ryan Howard      Phillies  159  581  704  182   98  25   1  58
# 10             Joe Mauer         Twins  140  521  608  181  128  36   4  13
# ...

# %%
merge.loc[41, 'Team'] = 'Nationals'
merge.loc[53, 'Team'] = 'Yankees'
merge.loc[90, 'Team'] = 'Brewers'
merge.loc[104, 'Team'] = 'Nationals'
merge.loc[106, 'Team'] = 'Brewers'
merge.loc[119, 'Team'] = 'Brewers'
merge.loc[125, 'Team'] = 'Astros'
merge.loc[128, 'Team'] = 'Padres'
merge.loc[135, 'Team'] = 'Cardinals'
merge.loc[144, 'Team'] = 'Pirates'
merge.loc[149, 'Team'] = 'Giants'
merge.loc[151, 'Team'] = 'Phillies'
merge.loc[154, 'Team'] = 'Mets'
merge.loc[157, 'Team'] = 'Cardinals'

# %%
print(merge.shape)
merge
# Out:
# (160, 36)
#                     Name          Team    G   AB   PA    H   1B  2B  3B  HR  \
# 0          Albert Pujols     Cardinals  143  535  634  177   94  33   1  49
# 1         Grady Sizemore       Indians  162  655  751  190   98  53  11  28
# 2         Carlos Beltran          Mets  140  510  617  140   60  38   1  41
# 3            Chase Utley      Phillies  160  658  739  203  127  40   4  32
# 4         Miguel Cabrera       Marlins  158  576  676  195  117  50   2  26
# 5            Derek Jeter       Yankees  154  623  715  214  158  39   3  14
# 6          Lance Berkman        Astros  152  536  646  169   95  29   0  45
# 7           Andruw Jones        Braves  156  565  669  148   78  29   0  41
# 8          Travis Hafner       Indians  129  454  564  140   66  31   1  42
# 9            Ryan Howard      Phillies  159  581  704  182   98  25   1  58
# 10             Joe Mauer         Twins  140  521  608  181  128  36   4  13
# ...

# %%
merge.dtypes
# Out:
# Name      object
# Team      object
# G          int64
# AB         int64
# PA         int64
# H          int64
# 1B         int64
# 2B         int64
# 3B         int64
# HR         int64
# R          int64
# RBI        int64
# BB         int64
# IBB        int64
# SO         int64
# BB%      float64
# K%       float64
# BB/K     float64
# BABIP    float64
# HBP        int64
# SF         int64
# SH         int64
# GDP        int64
# SB         int64
# CS         int64
# Def      float64
# ISO      float64
# wOBA     float64
# wRAA     float64
# AVG      float64
# OBP      float64
# SLG      float64
# OPS      float64
# WAR      float64
# wRC+       int64
# WPA      float64
# dtype: object

# %%
merge.to_csv('../csv/2006/2006_Merging_batters_stats.csv', index=None)
