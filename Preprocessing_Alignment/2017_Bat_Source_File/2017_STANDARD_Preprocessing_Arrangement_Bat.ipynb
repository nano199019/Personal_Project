# %%
from selenium import webdriver
import pandas as pd
import re
from pprint import pprint
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # StanDard Stats. Page1

# %%
res = requests.get('http://www.fangraphs.com/leaders.aspx?pos=all&stats=bat&lg=all&qual=y&type=0&season=2017&month=0&season1=2017&ind=0&team=0&rost=0&age=0&filter=&players=0&page=1_50')
soup = BeautifulSoup(res.content, 'html.parser')

player_dict = {}
for player in soup.select('tbody > tr'):
    try:
        name = player.select('td > a')[0].text
    except:
        name = None
    try:
        team = player.select('td > a')[1].text
    except:
        team = None
    player_spec = []
    for i in player.select('td')[3:]:
        player_spec.append(i.text)
    player_dict[(name, team)] = player_spec
print(len(player_dict.keys()))
pprint(player_dict)
# Out:
# 51
# {('Aaron Judge', 'Yankees'): ['155',
#                               '542',
#                               '678',
#                               '154',
#                               '75',
#                               '24',
#                               '3',
#                               '52',
#                               '128',
#                               '114',
#                               '127',
#                               '11',
#                               '208',
#                               '5',
#                               '4',
#                               '0',
#                               '15',
#                               '9',
#                               '4',
#                               '.284'],
#  ('Adam Jones', 'Orioles'): ['147',
#                              '597',
#                              '635',
#                              '170',
#                              '115',
#                              '28',
# ...

# %%
key_list = list(player_dict.keys())
key_list = key_list[1:]
key_list
# Out:
# [('Jose Altuve', 'Astros'),
#  ('Charlie Blackmon', 'Rockies'),
#  ('Avisail Garcia', 'White Sox'),
#  ('Daniel Murphy', 'Nationals'),
#  ('Justin Turner', 'Dodgers'),
#  ('Joey Votto', 'Reds'),
#  ('Buster Posey', 'Giants'),
#  ('Eric Hosmer', 'Royals'),
#  ('Jose Ramirez', 'Indians'),
#  ('Josh Reddick', 'Astros'),
#  ('Marcell Ozuna', 'Marlins'),
#  ('DJ LeMahieu', 'Rockies'),
#  ('Nolan Arenado', 'Rockies'),
#  ('Dee Gordon', 'Marlins'),
#  ('Freddie Freeman', 'Braves'),
#  ('Tommy Pham', 'Cardinals'),
#  ('Mike Trout', 'Angels'),
#  ('Joe Mauer', 'Twins'),
#  ('Jose Abreu', 'White Sox'),
#  ('Ender Inciarte', 'Braves'),
#  ('Ryan Zimmerman', 'Nationals'),
#  ('Marwin Gonzalez', 'Astros'),
#  ('Anthony Rendon', 'Nationals'),
#  ('Lorenzo Cain', 'Royals'),
#  ('Jean Segura', 'Mariners'),
#  ('Yulieski Gurriel', 'Astros'),
#  ('Paul Goldschmidt', 'Diamondbacks'),
#  ('Elvis Andrus', 'Rangers'),
#  ('Zack Cozart', 'Reds'),
#  ('Kris Bryant', 'Cubs'),
#  ('Corey Seager', 'Dodgers'),
# ...

# %%
name_list = []
team_list = []

for i in range(len(key_list)):
    name_list.append(key_list[i][0])

for i in range(len(key_list)):
    team_list.append(key_list[i][1])
    

print(name_list, '\n\n', team_list)
# Out:
# ['Jose Altuve', 'Charlie Blackmon', 'Avisail Garcia', 'Daniel Murphy', 'Justin Turner', 'Joey Votto', 'Buster Posey', 'Eric Hosmer', 'Jose Ramirez', 'Josh Reddick', 'Marcell Ozuna', 'DJ LeMahieu', 'Nolan Arenado', 'Dee Gordon', 'Freddie Freeman', 'Tommy Pham', 'Mike Trout', 'Joe Mauer', 'Jose Abreu', 'Ender Inciarte', 'Ryan Zimmerman', 'Marwin Gonzalez', 'Anthony Rendon', 'Lorenzo Cain', 'Jean Segura', 'Yulieski Gurriel', 'Paul Goldschmidt', 'Elvis Andrus', 'Zack Cozart', 'Kris Bryant', 'Corey Seager', 'Cesar Hernandez', 'David Peralta', 'Trey Mancini', 'Jonathan Schoop', 'Eddie Rosario', 'Chris Taylor', 'Whit Merrifield', 'Nelson Cruz', 'Joe Panik', 'Didi Gregorius', 'Melky Cabrera', 'Brandon Phillips', 'Adam Jones', 'Alex Bregman', 'Aaron Judge', 'George Springer', 'Christian Yelich', 'Corey Dickerson', 'Giancarlo Stanton']
#
# ...

# %%
name_list = pd.DataFrame({'Name' : name_list})
team_list = pd.DataFrame({'Team' : team_list})

name_list.insert(1, 'Team', team_list)
name_team_list = name_list

# %%
print(len(name_team_list))
name_team_list
# Out:
# 50
#                  Name          Team
# 0         Jose Altuve        Astros
# 1    Charlie Blackmon       Rockies
# 2      Avisail Garcia     White Sox
# 3       Daniel Murphy     Nationals
# 4       Justin Turner       Dodgers
# 5          Joey Votto          Reds
# 6        Buster Posey        Giants
# 7         Eric Hosmer        Royals
# 8        Jose Ramirez       Indians
# 9        Josh Reddick        Astros
# 10      Marcell Ozuna       Marlins
# 11        DJ LeMahieu       Rockies
# 12      Nolan Arenado       Rockies
# 13         Dee Gordon       Marlins
# 14    Freddie Freeman        Braves
# 15         Tommy Pham     Cardinals
# 16         Mike Trout        Angels
# 17          Joe Mauer         Twins
# 18         Jose Abreu     White Sox
# 19     Ender Inciarte        Braves
# 20     Ryan Zimmerman     Nationals
# 21    Marwin Gonzalez        Astros
# 22     Anthony Rendon     Nationals
# 23       Lorenzo Cain        Royals
# 24        Jean Segura      Mariners
# ...

# %%
name_team_list.loc[41, 'Team'] = 'Royals'
name_team_list.loc[42, 'Team'] = 'Angels'

name_team_list
# Out:
#                  Name          Team
# 0         Jose Altuve        Astros
# 1    Charlie Blackmon       Rockies
# 2      Avisail Garcia     White Sox
# 3       Daniel Murphy     Nationals
# 4       Justin Turner       Dodgers
# 5          Joey Votto          Reds
# 6        Buster Posey        Giants
# 7         Eric Hosmer        Royals
# 8        Jose Ramirez       Indians
# 9        Josh Reddick        Astros
# 10      Marcell Ozuna       Marlins
# 11        DJ LeMahieu       Rockies
# 12      Nolan Arenado       Rockies
# 13         Dee Gordon       Marlins
# 14    Freddie Freeman        Braves
# 15         Tommy Pham     Cardinals
# 16         Mike Trout        Angels
# 17          Joe Mauer         Twins
# 18         Jose Abreu     White Sox
# 19     Ender Inciarte        Braves
# 20     Ryan Zimmerman     Nationals
# 21    Marwin Gonzalez        Astros
# 22     Anthony Rendon     Nationals
# 23       Lorenzo Cain        Royals
# 24        Jean Segura      Mariners
# ...

# %%
real_stats = list(player_dict.values())

# %%
real_stats = real_stats[1:]
print(real_stats)
# Out:
# [['153', '590', '662', '204', '137', '39', '4', '24', '112', '81', '58', '3', '84', '9', '4', '1', '19', '32', '6', '.346'], ['159', '644', '725', '213', '127', '35', '14', '37', '137', '104', '65', '9', '135', '10', '3', '3', '4', '14', '10', '.331'], ['136', '518', '561', '171', '121', '27', '5', '18', '75', '80', '33', '5', '111', '9', '1', '0', '14', '5', '3', '.330'], ['144', '534', '593', '172', '103', '43', '3', '23', '94', '93', '52', '14', '77', '4', '3', '0', '16', '2', '0', '.322'], ['130', '457', '543', '147', '94', '32', '0', '21', '72', '71', '59', '5', '56', '19', '7', '1', '12', '7', '1', '.322'], ['162', '559', '707', '179', '108', '34', '1', '36', '106', '100', '134', '20', '83', '8', '6', '0', '16', '5', '1', '.320'], ['140', '494', '568', '158', '112', '34', '0', '12', '62', '67', '61', '13', '66', '8', '5', '0', '17', '6', '1', '.320'], ['162', '603', '671', '192', '135', '31', '1', '25', '98', '94', '66', '3', '104', '0', '2', '0', '20', '6', '1', '.318'], ['152
# ...

# %%
g_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[0]]
ab_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[1]]
pa_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[1]]
h_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[3]]
one_base_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[4]]
two_base_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[5]]
three_base_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[6]]
hr_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[7]]
r_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[8]]
rbi_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[9]]
bb_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[10]]
ibb_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[11]]
so_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[12]]
hbp_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[13]]
sf_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[14]]
sh_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[15]]
gdp_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[16]]
sb_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[17]]
cs_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[18]]
avg_num = [float(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[19]]

# %%
temporary = pd.DataFrame({'G' : g_num, 'AB' : ab_num, 'PA' : pa_num, 'H' : h_num, '1B' : one_base_num, '2B' : two_base_num, '3B' : three_base_num, 'HR' : hr_num, 'R' : r_num, 'RBI' : rbi_num, 'BB' : bb_num, 'IBB' : ibb_num, 'SO' : so_num, 'HBP' : hbp_num, 'SF' : sf_num, 'SH' : sh_num, 'GDP' : gdp_num, 'SB' : sb_num, 'CS' : cs_num, 'AVG' : avg_num})

# %%
temporary
# Out:
#      1B  2B  3B   AB    AVG   BB  CS    G  GDP    H  HBP  HR  IBB   PA    R  \
# 0   137  39   4  590  0.346   58   6  153   19  204    9  24    3  590  112
# 1   127  35  14  644  0.331   65  10  159    4  213   10  37    9  644  137
# 2   121  27   5  518  0.330   33   3  136   14  171    9  18    5  518   75
# 3   103  43   3  534  0.322   52   0  144   16  172    4  23   14  534   94
# 4    94  32   0  457  0.322   59   1  130   12  147   19  21    5  457   72
# 5   108  34   1  559  0.320  134   1  162   16  179    8  36   20  559  106
# 6   112  34   0  494  0.320   61   1  140   17  158    8  12   13  494   62
# 7   135  31   1  603  0.318   66   1  162   20  192    0  25    3  603   98
# 8    95  56   6  585  0.318   52   5  152   13  186    3  29    5  585  107
# 9    99  34   4  477  0.314   43   3  134    9  150    0  13    1  477   77
# 10  122  30   2  613  0.312   64   3  159   18  191    0  37    4  613   93
# ...

# %%
asdasd = temporary.copy()

# %%
merged_data1 = pd.concat([name_team_list, asdasd], axis=1)
merged_data1
# Out:
#                  Name          Team   1B  2B  3B   AB    AVG   BB  CS    G  \
# 0         Jose Altuve        Astros  137  39   4  590  0.346   58   6  153
# 1    Charlie Blackmon       Rockies  127  35  14  644  0.331   65  10  159
# 2      Avisail Garcia     White Sox  121  27   5  518  0.330   33   3  136
# 3       Daniel Murphy     Nationals  103  43   3  534  0.322   52   0  144
# 4       Justin Turner       Dodgers   94  32   0  457  0.322   59   1  130
# 5          Joey Votto          Reds  108  34   1  559  0.320  134   1  162
# 6        Buster Posey        Giants  112  34   0  494  0.320   61   1  140
# 7         Eric Hosmer        Royals  135  31   1  603  0.318   66   1  162
# 8        Jose Ramirez       Indians   95  56   6  585  0.318   52   5  152
# 9        Josh Reddick        Astros   99  34   4  477  0.314   43   3  134
# 10      Marcell Ozuna       Marlins  122  30   2  613  0.312   64   3  159
# ...

# %% [markdown]
# ## 2017 StanDard Stats. Page2

# %%
res = requests.get('http://www.fangraphs.com/leaders.aspx?pos=all&stats=bat&lg=all&qual=y&type=0&season=2017&month=0&season1=2017&ind=0&team=0&rost=0&age=0&filter=&players=0&page=2_50')
soup = BeautifulSoup(res.content, 'html.parser')

player_dict2 = {}
for player in soup.select('tbody > tr'):
    try:
        name = player.select('td > a')[0].text
    except:
        name = None
    try:
        team = player.select('td > a')[1].text
    except:
        team = None
    player_spec2 = []
    for i in player.select('td')[3:]:
        player_spec2.append(i.text)
    player_dict2[(name, team)] = player_spec2
print(len(player_dict2.keys()))
pprint(player_dict2)
# Out:
# 51
# {(None, None): [],
#  ('Andrelton Simmons', 'Angels'): ['158',
#                                    '589',
#                                    '647',
#                                    '164',
#                                    '110',
#                                    '38',
#                                    '2',
#                                    '14',
#                                    '77',
#                                    '69',
#                                    '47',
#                                    '0',
#                                    '67',
#                                    '3',
#                                    '8',
#                                    '0',
#                                    '20',
#                                    '19',
#                                    '6',
#                                    '.278'],
#  ('Andrew Benintendi', 'Red Sox'): ['151',
#                                     '573',
# ...

# %%
key_list2 = list(player_dict2.keys())
key_list2 = key_list2[1:]
key_list2
# Out:
# [('Odubel Herrera', 'Phillies'),
#  ('Robinson Cano', 'Mariners'),
#  ('Asdrubal Cabrera', 'Mets'),
#  ('Andrew McCutchen', 'Pirates'),
#  ('Andrelton Simmons', 'Angels'),
#  ('J.T. Realmuto', 'Marlins'),
#  ('Gary Sanchez', 'Yankees'),
#  ('Domingo Santana', 'Brewers'),
#  ('Tim Beckham', None),
#  ('Jed Lowrie', 'Athletics'),
#  ('Orlando Arcia', 'Brewers'),
#  ('Ben Gamel', 'Mariners'),
#  ('Nick Markakis', 'Braves'),
#  ('Yadier Molina', 'Cardinals'),
#  ('Chase Headley', 'Yankees'),
#  ('Francisco Lindor', 'Indians'),
#  ('Travis Shaw', 'Brewers'),
#  ('Xander Bogaerts', 'Red Sox'),
#  ('Javier Baez', 'Cubs'),
#  ('Justin Upton', None),
#  ('Anthony Rizzo', 'Cubs'),
#  ('Mike Moustakas', 'Royals'),
#  ('Nick Castellanos', 'Tigers'),
#  ('Denard Span', 'Giants'),
#  ('Josh Harrison', 'Pirates'),
#  ('Ryon Healy', 'Athletics'),
#  ('Brian Dozier', 'Twins'),
#  ('Andrew Benintendi', 'Red Sox'),
#  ('Justin Smoak', 'Blue Jays'),
#  ('Mark Reynolds', 'Rockies'),
# ...

# %%
name_list2 = []
team_list2 = []

for i in range(len(key_list2)):
    name_list2.append(key_list2[i][0])

for i in range(len(key_list2)):
    team_list2.append(key_list2[i][1])
    

print(name_list2, '\n\n', team_list2)
# Out:
# ['Odubel Herrera', 'Robinson Cano', 'Asdrubal Cabrera', 'Andrew McCutchen', 'Andrelton Simmons', 'J.T. Realmuto', 'Gary Sanchez', 'Domingo Santana', 'Tim Beckham', 'Jed Lowrie', 'Orlando Arcia', 'Ben Gamel', 'Nick Markakis', 'Yadier Molina', 'Chase Headley', 'Francisco Lindor', 'Travis Shaw', 'Xander Bogaerts', 'Javier Baez', 'Justin Upton', 'Anthony Rizzo', 'Mike Moustakas', 'Nick Castellanos', 'Denard Span', 'Josh Harrison', 'Ryon Healy', 'Brian Dozier', 'Andrew Benintendi', 'Justin Smoak', 'Mark Reynolds', 'Cody Bellinger', 'Yolmer Sanchez', 'Yonder Alonso', 'Mookie Betts', 'Brett Gardner', 'David Freese', 'Manuel Margot', 'Yasiel Puig', 'Carlos Gonzalez', 'Shin-Soo Choo', 'Evan Longoria', 'Eugenio Suarez', 'Hunter Pence', 'Carlos Santana', 'Manny Machado', 'Jose Peraza', 'Edwin Encarnacion', 'Tim Anderson', 'Jorge Polanco', 'Kevin Pillar']
#
# ...

# %%
name_list2 = pd.DataFrame({'Name' : name_list2})
team_list2 = pd.DataFrame({'Team' : team_list2})

name_list2.insert(1, 'Team', team_list2)
name_team_list2 = name_list2

# %%
print(len(name_team_list2))
name_team_list2
# Out:
# 50
#                  Name       Team
# 0      Odubel Herrera   Phillies
# 1       Robinson Cano   Mariners
# 2    Asdrubal Cabrera       Mets
# 3    Andrew McCutchen    Pirates
# 4   Andrelton Simmons     Angels
# 5       J.T. Realmuto    Marlins
# 6        Gary Sanchez    Yankees
# 7     Domingo Santana    Brewers
# 8         Tim Beckham       None
# 9          Jed Lowrie  Athletics
# 10      Orlando Arcia    Brewers
# 11          Ben Gamel   Mariners
# 12      Nick Markakis     Braves
# 13      Yadier Molina  Cardinals
# 14      Chase Headley    Yankees
# 15   Francisco Lindor    Indians
# 16        Travis Shaw    Brewers
# 17    Xander Bogaerts    Red Sox
# 18        Javier Baez       Cubs
# 19       Justin Upton       None
# 20      Anthony Rizzo       Cubs
# 21     Mike Moustakas     Royals
# 22   Nick Castellanos     Tigers
# 23        Denard Span     Giants
# 24      Josh Harrison    Pirates
# 25         Ryon Healy  Athletics
# 26       Brian Dozier      Twins
# ...

# %%
name_team_list2.loc[8, 'Team'] = 'Orioles'
name_team_list2.loc[19, 'Team'] = 'Angels'
name_team_list2.loc[32, 'Team'] = 'Mariners'

name_team_list2
# Out:
#                  Name       Team
# 0      Odubel Herrera   Phillies
# 1       Robinson Cano   Mariners
# 2    Asdrubal Cabrera       Mets
# 3    Andrew McCutchen    Pirates
# 4   Andrelton Simmons     Angels
# 5       J.T. Realmuto    Marlins
# 6        Gary Sanchez    Yankees
# 7     Domingo Santana    Brewers
# 8         Tim Beckham    Orioles
# 9          Jed Lowrie  Athletics
# 10      Orlando Arcia    Brewers
# 11          Ben Gamel   Mariners
# 12      Nick Markakis     Braves
# 13      Yadier Molina  Cardinals
# 14      Chase Headley    Yankees
# 15   Francisco Lindor    Indians
# 16        Travis Shaw    Brewers
# 17    Xander Bogaerts    Red Sox
# 18        Javier Baez       Cubs
# 19       Justin Upton     Angels
# 20      Anthony Rizzo       Cubs
# 21     Mike Moustakas     Royals
# 22   Nick Castellanos     Tigers
# 23        Denard Span     Giants
# 24      Josh Harrison    Pirates
# 25         Ryon Healy  Athletics
# 26       Brian Dozier      Twins
# ...

# %%
real_stats2 = list(player_dict2.values())

# %%
real_stats2 = real_stats2[1:]
print(real_stats2)
# Out:
# [['138', '526', '563', '148', '89', '42', '3', '14', '67', '56', '31', '4', '126', '4', '2', '0', '13', '8', '5', '.281'], ['150', '592', '648', '166', '110', '33', '0', '23', '79', '97', '49', '8', '85', '4', '3', '0', '18', '1', '0', '.280'], ['135', '479', '540', '134', '88', '32', '0', '14', '66', '59', '50', '1', '83', '5', '5', '1', '19', '3', '2', '.280'], ['156', '570', '650', '159', '99', '30', '2', '28', '94', '88', '73', '5', '116', '4', '3', '0', '10', '11', '5', '.279'], ['158', '589', '647', '164', '110', '38', '2', '14', '77', '69', '47', '0', '67', '3', '8', '0', '20', '19', '6', '.278'], ['141', '532', '579', '148', '95', '31', '5', '17', '68', '65', '36', '4', '106', '8', '3', '0', '13', '8', '2', '.278'], ['122', '471', '525', '131', '78', '20', '0', '33', '79', '90', '40', '1', '120', '10', '4', '0', '9', '2', '1', '.278'], ['151', '525', '607', '146', '87', '29', '0', '30', '88', '85', '73', '2', '178', '6', '3', '0', '12', '15', '4', '.278'], ['137', '533', '575
# ...

# %%
g_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[0]]
ab_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[1]]
pa_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[1]]
h_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[3]]
one_base_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[4]]
two_base_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[5]]
three_base_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[6]]
hr_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[7]]
r_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[8]]
rbi_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[9]]
bb_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[10]]
ibb_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[11]]
so_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[12]]
hbp_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[13]]
sf_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[14]]
sh_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[15]]
gdp_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[16]]
sb_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[17]]
cs_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[18]]
avg_num2 = [float(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[19]]

# %%
temporary2 = pd.DataFrame({'G' : g_num2, 'AB' : ab_num2, 'PA' : pa_num2, 'H' : h_num2, '1B' : one_base_num2, '2B' : two_base_num2, '3B' : three_base_num2, 'HR' : hr_num2, 'R' : r_num2, 'RBI' : rbi_num2, 'BB' : bb_num2, 'IBB' : ibb_num2, 'SO' : so_num2, 'HBP' : hbp_num2, 'SF' : sf_num2, 'SH' : sh_num2, 'GDP' : gdp_num2, 'SB' : sb_num2, 'CS' : cs_num2, 'AVG' : avg_num2})

# %%
temporary2
# Out:
#      1B  2B  3B   AB    AVG   BB  CS    G  GDP    H  HBP  HR  IBB   PA    R  \
# 0    89  42   3  526  0.281   31   5  138   13  148    4  14    4  526   67
# 1   110  33   0  592  0.280   49   0  150   18  166    4  23    8  592   79
# 2    88  32   0  479  0.280   50   2  135   19  134    5  14    1  479   66
# 3    99  30   2  570  0.279   73   5  156   10  159    4  28    5  570   94
# 4   110  38   2  589  0.278   47   6  158   20  164    3  14    0  589   77
# 5    95  31   5  532  0.278   36   2  141   13  148    8  17    4  532   68
# 6    78  20   0  471  0.278   40   1  122    9  131   10  33    1  471   79
# 7    87  29   0  525  0.278   73   4  151   12  146    6  30    2  525   88
# 8   103  18   5  533  0.278   36   5  137   10  148    4  22    0  533   67
# 9    91  49   3  567  0.277   73   1  153   10  157    2  14    2  567   86
# 10  106  17   2  506  0.277   36   7  153   10  140    1  15    9  506   56
# ...

# %%
asdasd2 = temporary2.copy()

# %%
merged_data2 = pd.concat([name_team_list2, asdasd2], axis=1)
merged_data2
# Out:
#                  Name       Team   1B  2B  3B   AB    AVG   BB  CS    G  GDP  \
# 0      Odubel Herrera   Phillies   89  42   3  526  0.281   31   5  138   13
# 1       Robinson Cano   Mariners  110  33   0  592  0.280   49   0  150   18
# 2    Asdrubal Cabrera       Mets   88  32   0  479  0.280   50   2  135   19
# 3    Andrew McCutchen    Pirates   99  30   2  570  0.279   73   5  156   10
# 4   Andrelton Simmons     Angels  110  38   2  589  0.278   47   6  158   20
# 5       J.T. Realmuto    Marlins   95  31   5  532  0.278   36   2  141   13
# 6        Gary Sanchez    Yankees   78  20   0  471  0.278   40   1  122    9
# 7     Domingo Santana    Brewers   87  29   0  525  0.278   73   4  151   12
# 8         Tim Beckham    Orioles  103  18   5  533  0.278   36   5  137   10
# 9          Jed Lowrie  Athletics   91  49   3  567  0.277   73   1  153   10
# 10      Orlando Arcia    Brewers  106  17   2  506  0.277   36   7  153   10
# ...

# %% [markdown]
# ## 2017 StanDard Stats. Page3

# %%
res = requests.get('http://www.fangraphs.com/leaders.aspx?pos=all&stats=bat&lg=all&qual=y&type=0&season=2017&month=0&season1=2017&ind=0&team=0&rost=0&age=0&filter=&players=0&page=3_50')
soup = BeautifulSoup(res.content, 'html.parser')

player_dict3 = {}
for player in soup.select('tbody > tr'):
    try:
        name = player.select('td > a')[0].text
    except:
        name = None
    try:
        team = player.select('td > a')[1].text
    except:
        team = None
    player_spec3 = []
    for i in player.select('td')[3:]:
        player_spec3.append(i.text)
    player_dict3[(name, team)] = player_spec3
print(len(player_dict3.keys()))
pprint(player_dict3)
# Out:
# 45
# {('Adam Duvall', 'Reds'): ['157',
#                            '587',
#                            '647',
#                            '146',
#                            '75',
#                            '37',
#                            '3',
#                            '31',
#                            '78',
#                            '99',
#                            '39',
#                            '1',
#                            '170',
#                            '10',
#                            '11',
#                            '0',
#                            '11',
#                            '5',
#                            '3',
#                            '.249'],
#  ('Albert Pujols', 'Angels'): ['149',
#                                '593',
#                                '636',
#                                '143',
#                                '103',
#                                '17',
#                                '0',
# ...

# %%
key_list3 = list(player_dict3.keys())
key_list3 = key_list3[1:]
key_list3
# Out:
# [('Yangervis Solarte', 'Padres'),
#  ('Josh Bell', 'Pirates'),
#  ('Jordy Mercer', 'Pirates'),
#  ('Freddy Galvis', 'Phillies'),
#  ('Jay Bruce', None),
#  ('Byron Buxton', 'Twins'),
#  ('Brandon Crawford', 'Giants'),
#  ('Nomar Mazara', 'Rangers'),
#  ('Alcides Escobar', 'Royals'),
#  ('Kendrys Morales', 'Blue Jays'),
#  ('Miguel Cabrera', 'Tigers'),
#  ('Kyle Seager', 'Mariners'),
#  ('Adam Duvall', 'Reds'),
#  ('Jake Lamb', 'Diamondbacks'),
#  ('Billy Hamilton', 'Reds'),
#  ('Khris Davis', 'Athletics'),
#  ('Eric Thames', 'Brewers'),
#  ('Logan Morrison', 'Rays'),
#  ('Mitch Moreland', 'Red Sox'),
#  ('Jose Reyes', 'Mets'),
#  ('Jackie Bradley Jr.', 'Red Sox'),
#  ('Kole Calhoun', 'Angels'),
#  ('Wil Myers', 'Padres'),
#  ('Matt Joyce', 'Athletics'),
#  ('Max Kepler', 'Twins'),
#  ('Hanley Ramirez', 'Red Sox'),
#  ('Matt Carpenter', 'Cardinals'),
#  ('Albert Pujols', 'Angels'),
#  ('Tommy Joseph', 'Phillies'),
#  ('Steven Souza Jr.', 'Rays'),
#  ('Trevor Story', 'Rockies'),
# ...

# %%
name_list3 = []
team_list3 = []

for i in range(len(key_list3)):
    name_list3.append(key_list3[i][0])

for i in range(len(key_list3)):
    team_list3.append(key_list3[i][1])
    

print(name_list3, '\n\n', team_list3)
# Out:
# ['Yangervis Solarte', 'Josh Bell', 'Jordy Mercer', 'Freddy Galvis', 'Jay Bruce', 'Byron Buxton', 'Brandon Crawford', 'Nomar Mazara', 'Alcides Escobar', 'Kendrys Morales', 'Miguel Cabrera', 'Kyle Seager', 'Adam Duvall', 'Jake Lamb', 'Billy Hamilton', 'Khris Davis', 'Eric Thames', 'Logan Morrison', 'Mitch Moreland', 'Jose Reyes', 'Jackie Bradley Jr.', 'Kole Calhoun', 'Wil Myers', 'Matt Joyce', 'Max Kepler', 'Hanley Ramirez', 'Matt Carpenter', 'Albert Pujols', 'Tommy Joseph', 'Steven Souza Jr.', 'Trevor Story', 'Ian Kinsler', 'Mark Trumbo', 'Scott Schebler', 'Dansby Swanson', 'Carlos Beltran', 'Maikel Franco', 'Chris Davis', 'Todd Frazier', 'Curtis Granderson', 'Joey Gallo', 'Alex Gordon', 'Rougned Odor', 'Jose Bautista']
#
# ...

# %%
name_list3 = pd.DataFrame({'Name' : name_list3})
team_list3 = pd.DataFrame({'Team' : team_list3})

name_list3.insert(1, 'Team', team_list3)
name_team_list3 = name_list3

# %%
print(len(name_team_list3))
name_team_list3
# Out:
# 44
#                   Name          Team
# 0    Yangervis Solarte        Padres
# 1            Josh Bell       Pirates
# 2         Jordy Mercer       Pirates
# 3        Freddy Galvis      Phillies
# 4            Jay Bruce          None
# 5         Byron Buxton         Twins
# 6     Brandon Crawford        Giants
# 7         Nomar Mazara       Rangers
# 8      Alcides Escobar        Royals
# 9      Kendrys Morales     Blue Jays
# 10      Miguel Cabrera        Tigers
# 11         Kyle Seager      Mariners
# 12         Adam Duvall          Reds
# 13           Jake Lamb  Diamondbacks
# 14      Billy Hamilton          Reds
# 15         Khris Davis     Athletics
# 16         Eric Thames       Brewers
# 17      Logan Morrison          Rays
# 18      Mitch Moreland       Red Sox
# 19          Jose Reyes          Mets
# 20  Jackie Bradley Jr.       Red Sox
# 21        Kole Calhoun        Angels
# 22           Wil Myers        Padres
# 23          Matt Joyce     Athletics
# ...

# %%
name_team_list3.loc[4, 'Team'] = 'Indians'
name_team_list3.loc[38, 'Team'] = 'Yankees'
name_team_list3.loc[39, 'Team'] = 'Dodgers'

name_team_list3
# Out:
#                   Name          Team
# 0    Yangervis Solarte        Padres
# 1            Josh Bell       Pirates
# 2         Jordy Mercer       Pirates
# 3        Freddy Galvis      Phillies
# 4            Jay Bruce       Indians
# 5         Byron Buxton         Twins
# 6     Brandon Crawford        Giants
# 7         Nomar Mazara       Rangers
# 8      Alcides Escobar        Royals
# 9      Kendrys Morales     Blue Jays
# 10      Miguel Cabrera        Tigers
# 11         Kyle Seager      Mariners
# 12         Adam Duvall          Reds
# 13           Jake Lamb  Diamondbacks
# 14      Billy Hamilton          Reds
# 15         Khris Davis     Athletics
# 16         Eric Thames       Brewers
# 17      Logan Morrison          Rays
# 18      Mitch Moreland       Red Sox
# 19          Jose Reyes          Mets
# 20  Jackie Bradley Jr.       Red Sox
# 21        Kole Calhoun        Angels
# 22           Wil Myers        Padres
# 23          Matt Joyce     Athletics
# ...

# %%
real_stats3 = list(player_dict3.values())

# %%
real_stats3 = real_stats3[1:]
print(real_stats3)
# Out:
# [['128', '466', '512', '119', '80', '21', '0', '18', '49', '64', '37', '4', '61', '5', '4', '0', '18', '3', '0', '.255'], ['159', '549', '620', '140', '82', '26', '6', '26', '75', '90', '66', '4', '117', '1', '4', '0', '15', '2', '4', '.255'], ['145', '502', '558', '128', '85', '24', '5', '14', '52', '58', '51', '13', '88', '3', '2', '0', '16', '0', '4', '.255'], ['162', '608', '663', '155', '108', '29', '6', '12', '71', '61', '45', '2', '111', '4', '4', '2', '12', '14', '5', '.255'], ['146', '555', '617', '141', '74', '29', '2', '36', '82', '101', '57', '0', '139', '2', '3', '0', '11', '1', '1', '.254'], ['140', '462', '511', '117', '81', '14', '6', '16', '69', '51', '38', '2', '150', '4', '2', '5', '1', '29', '1', '.253'], ['144', '518', '570', '131', '82', '34', '1', '14', '58', '77', '42', '3', '113', '1', '9', '0', '18', '3', '5', '.253'], ['148', '554', '616', '140', '88', '30', '2', '20', '64', '101', '55', '6', '127', '4', '3', '0', '12', '2', '2', '.253'], ['162', '599', '62
# ...

# %%
g_num3 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats3))[0]]
ab_num3 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats3))[1]]
pa_num3 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats3))[1]]
h_num3 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats3))[3]]
one_base_num3 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats3))[4]]
two_base_num3 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats3))[5]]
three_base_num3 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats3))[6]]
hr_num3 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats3))[7]]
r_num3 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats3))[8]]
rbi_num3 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats3))[9]]
bb_num3 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats3))[10]]
ibb_num3 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats3))[11]]
so_num3 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats3))[12]]
hbp_num3 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats3))[13]]
sf_num3 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats3))[14]]
sh_num3 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats3))[15]]
gdp_num3 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats3))[16]]
sb_num3 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats3))[17]]
cs_num3 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats3))[18]]
avg_num3 = [float(re.sub(r' %', '', x)) for x in list(zip(*real_stats3))[19]]

# %%
temporary3 = pd.DataFrame({'G' : g_num3, 'AB' : ab_num3, 'PA' : pa_num3, 'H' : h_num3, '1B' : one_base_num3, '2B' : two_base_num3, '3B' : three_base_num3, 'HR' : hr_num3, 'R' : r_num3, 'RBI' : rbi_num3, 'BB' : bb_num3, 'IBB' : ibb_num3, 'SO' : so_num3, 'HBP' : hbp_num3, 'SF' : sf_num3, 'SH' : sh_num3, 'GDP' : gdp_num3, 'SB' : sb_num3, 'CS' : cs_num3, 'AVG' : avg_num3})

# %%
temporary3
# Out:
#      1B  2B  3B   AB    AVG   BB  CS    G  GDP    H  HBP  HR  IBB   PA   R  \
# 0    80  21   0  466  0.255   37   0  128   18  119    5  18    4  466  49
# 1    82  26   6  549  0.255   66   4  159   15  140    1  26    4  549  75
# 2    85  24   5  502  0.255   51   4  145   16  128    3  14   13  502  52
# 3   108  29   6  608  0.255   45   5  162   12  155    4  12    2  608  71
# 4    74  29   2  555  0.254   57   1  146   11  141    2  36    0  555  82
# 5    81  14   6  462  0.253   38   1  140    1  117    4  16    2  462  69
# 6    82  34   1  518  0.253   42   5  144   18  131    1  14    3  518  58
# 7    88  30   2  554  0.253   55   2  148   12  140    4  20    6  554  64
# 8   103  36   5  599  0.250   15   7  162   14  150    4   6    1  599  71
# 9    86  25   0  557  0.250   43   0  150   22  139    5  28    2  557  67
# 10   79  22   0  469  0.249   54   1  130   15  117    3  16    6  469  50
# ...

# %%
asdasd3 = temporary3.copy()

# %%
merged_data3 = pd.concat([name_team_list3, asdasd3], axis=1)
merged_data3
# Out:
#                   Name          Team   1B  2B  3B   AB    AVG   BB  CS    G  \
# 0    Yangervis Solarte        Padres   80  21   0  466  0.255   37   0  128
# 1            Josh Bell       Pirates   82  26   6  549  0.255   66   4  159
# 2         Jordy Mercer       Pirates   85  24   5  502  0.255   51   4  145
# 3        Freddy Galvis      Phillies  108  29   6  608  0.255   45   5  162
# 4            Jay Bruce       Indians   74  29   2  555  0.254   57   1  146
# 5         Byron Buxton         Twins   81  14   6  462  0.253   38   1  140
# 6     Brandon Crawford        Giants   82  34   1  518  0.253   42   5  144
# 7         Nomar Mazara       Rangers   88  30   2  554  0.253   55   2  148
# 8      Alcides Escobar        Royals  103  36   5  599  0.250   15   7  162
# 9      Kendrys Morales     Blue Jays   86  25   0  557  0.250   43   0  150
# 10      Miguel Cabrera        Tigers   79  22   0  469  0.249   54   1  130
# ...

# %% [markdown]
# ## Merging 2017 StanDard Bat Data

# %%
merging_2017_std_bat = pd.concat([merged_data1, merged_data2])
merging_2017_std_bat = pd.concat([merging_2017_std_bat, merged_data3])
merging_2017_std_bat = merging_2017_std_bat.reset_index()

del merging_2017_std_bat['index']

print(merging_2017_std_bat.shape)
# Out:
# (144, 22)

# %%
to_list = merging_2017_std_bat.columns.tolist()
print(to_list)
# Out:
# ['Name', 'Team', '1B', '2B', '3B', 'AB', 'AVG', 'BB', 'CS', 'G', 'GDP', 'H', 'HBP', 'HR', 'IBB', 'PA', 'R', 'RBI', 'SB', 'SF', 'SH', 'SO']

# %%
to_list = ['Name', 'Team', 'G', 'AB', 'PA', 'H', '1B', '2B', '3B', 'HR', 'R', 'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SF', 'SH', 'GDP', 'SB', 'CS', 'AVG']
merging_2017_std_bat = merging_2017_std_bat[to_list]

merging_2017_std_bat = merging_2017_std_bat.reset_index()
del merging_2017_std_bat['index']

print(merging_2017_std_bat.shape)
merging_2017_std_bat
# Out:
# (144, 22)
#                    Name          Team    G   AB   PA    H   1B  2B  3B  HR  \
# 0           Jose Altuve        Astros  153  590  590  204  137  39   4  24
# 1      Charlie Blackmon       Rockies  159  644  644  213  127  35  14  37
# 2        Avisail Garcia     White Sox  136  518  518  171  121  27   5  18
# 3         Daniel Murphy     Nationals  144  534  534  172  103  43   3  23
# 4         Justin Turner       Dodgers  130  457  457  147   94  32   0  21
# 5            Joey Votto          Reds  162  559  559  179  108  34   1  36
# 6          Buster Posey        Giants  140  494  494  158  112  34   0  12
# 7           Eric Hosmer        Royals  162  603  603  192  135  31   1  25
# 8          Jose Ramirez       Indians  152  585  585  186   95  56   6  29
# 9          Josh Reddick        Astros  134  477  477  150   99  34   4  13
# 10        Marcell Ozuna       Marlins  159  613  613  191  122  30   2  37
# ...

# %%
merging_2017_std_bat.to_csv('Merging_2017_STD_bat.csv', index=None)
