# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re
from pprint import pprint

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 2017 StanDard Stats. Page1

# %%
res = requests.get('http://www.fangraphs.com/leaders.aspx?pos=all&stats=pit&lg=all&qual=y&type=0&season=2017&month=0&season1=2017&ind=0&team=0&rost=0&age=0&filter=&players=0&page=1_50')
soup = BeautifulSoup(res.content, 'html.parser')

player_dict = {}
for player in soup.select('tbody > tr'):
    try:
        name = player.select('td > a')[0].text
    except:
        name = None
    try:
        team = player.select('td > a')[1].text
    except:
        team = None
    player_spec = []
    for i in player.select('td')[3:]:
        player_spec.append(i.text)
    player_dict[(name, team)] = player_spec
print(len(player_dict.keys()))
pprint(player_dict)
# Out:
# 51
# {('Aaron Nola', 'Phillies'): ['12',
#                               '11',
#                               '3.54',
#                               '27',
#                               '27',
#                               '0',
#                               '0',
#                               '0',
#                               '0',
#                               '0',
#                               '168.0',
#                               '693',
#                               '154',
#                               '67',
#                               '66',
#                               '18',
#                               '49',
#                               '2',
#                               '2',
#                               '1',
#                               '0',
#                               '184'],
#  ('Alex Cobb', 'Rays'): ['12',
#                          '10',
#                          '3.66',
#                          '29',
# ...

# %%
key_list = list(player_dict.keys())
key_list = key_list[1:]
key_list
# Out:
# [('Corey Kluber', 'Indians'),
#  ('Clayton Kershaw', 'Dodgers'),
#  ('Max Scherzer', 'Nationals'),
#  ('Stephen Strasburg', 'Nationals'),
#  ('Robbie Ray', 'Diamondbacks'),
#  ('Chris Sale', 'Red Sox'),
#  ('Gio Gonzalez', 'Nationals'),
#  ('Luis Severino', 'Yankees'),
#  ('Marcus Stroman', 'Blue Jays'),
#  ('Zack Greinke', 'Diamondbacks'),
#  ('Ervin Santana', 'Twins'),
#  ('Carlos Carrasco', 'Indians'),
#  ('Drew Pomeranz', 'Red Sox'),
#  ('Justin Verlander', None),
#  ('Andrew Cashner', 'Rangers'),
#  ('Lance Lynn', 'Cardinals'),
#  ('Jimmy Nelson', 'Brewers'),
#  ('Jake Arrieta', 'Cubs'),
#  ('Jacob deGrom', 'Mets'),
#  ('Aaron Nola', 'Phillies'),
#  ('Sonny Gray', None),
#  ('Carlos Martinez', 'Cardinals'),
#  ('Alex Cobb', 'Rays'),
#  ('Jose Urena', 'Marlins'),
#  ('Michael Fulmer', 'Tigers'),
#  ('Yu Darvish', None),
#  ('Jhoulys Chacin', 'Padres'),
#  ('Zach Davies', 'Brewers'),
#  ('Mike Leake', None),
#  ('Patrick Corbin', 'Diamondbacks'),
#  ('Chris Archer', 'Rays'),
# ...

# %%
name_list = []
team_list = []

for i in range(len(key_list)):
    name_list.append(key_list[i][0])

for i in range(len(key_list)):
    team_list.append(key_list[i][1])
    

print(name_list, '\n\n', team_list)
# Out:
# ['Corey Kluber', 'Clayton Kershaw', 'Max Scherzer', 'Stephen Strasburg', 'Robbie Ray', 'Chris Sale', 'Gio Gonzalez', 'Luis Severino', 'Marcus Stroman', 'Zack Greinke', 'Ervin Santana', 'Carlos Carrasco', 'Drew Pomeranz', 'Justin Verlander', 'Andrew Cashner', 'Lance Lynn', 'Jimmy Nelson', 'Jake Arrieta', 'Jacob deGrom', 'Aaron Nola', 'Sonny Gray', 'Carlos Martinez', 'Alex Cobb', 'Jose Urena', 'Michael Fulmer', 'Yu Darvish', 'Jhoulys Chacin', 'Zach Davies', 'Mike Leake', 'Patrick Corbin', 'Chris Archer', 'Michael Wacha', 'Ivan Nova', 'Jose Quintana', 'Jason Vargas', 'Trevor Bauer', 'Dylan Bundy', 'Gerrit Cole', 'Dan Straily', 'R.A. Dickey', 'Jon Lester', 'German Marquez', 'Jeff Samardzija', 'Julio Teheran', 'John Lackey', 'Rick Porcello', 'Tanner Roark', 'Luis Perdomo', 'Kevin Gausman', 'Masahiro Tanaka']
#
# ...

# %%
name_list = pd.DataFrame({'Name' : name_list})
team_list = pd.DataFrame({'Team' : team_list})

name_list.insert(1, 'Team', team_list)
name_team_list = name_list

# %%
print(len(name_team_list))
name_team_list
# Out:
# 50
#                  Name          Team
# 0        Corey Kluber       Indians
# 1     Clayton Kershaw       Dodgers
# 2        Max Scherzer     Nationals
# 3   Stephen Strasburg     Nationals
# 4          Robbie Ray  Diamondbacks
# 5          Chris Sale       Red Sox
# 6        Gio Gonzalez     Nationals
# 7       Luis Severino       Yankees
# 8      Marcus Stroman     Blue Jays
# 9        Zack Greinke  Diamondbacks
# 10      Ervin Santana         Twins
# 11    Carlos Carrasco       Indians
# 12      Drew Pomeranz       Red Sox
# 13   Justin Verlander          None
# 14     Andrew Cashner       Rangers
# 15         Lance Lynn     Cardinals
# 16       Jimmy Nelson       Brewers
# 17       Jake Arrieta          Cubs
# 18       Jacob deGrom          Mets
# 19         Aaron Nola      Phillies
# 20         Sonny Gray          None
# 21    Carlos Martinez     Cardinals
# 22          Alex Cobb          Rays
# 23         Jose Urena       Marlins
# 24     Michael Fulmer        Tigers
# ...

# %%
name_team_list.loc[13, 'Team'] = 'Astros'
name_team_list.loc[20, 'Team'] = 'Yankees'
name_team_list.loc[25, 'Team'] = 'Dodgers'
name_team_list.loc[28, 'Team'] = 'Mariners'
name_team_list.loc[33, 'Team'] = 'Cubs'


name_team_list
# Out:
#                  Name          Team
# 0        Corey Kluber       Indians
# 1     Clayton Kershaw       Dodgers
# 2        Max Scherzer     Nationals
# 3   Stephen Strasburg     Nationals
# 4          Robbie Ray  Diamondbacks
# 5          Chris Sale       Red Sox
# 6        Gio Gonzalez     Nationals
# 7       Luis Severino       Yankees
# 8      Marcus Stroman     Blue Jays
# 9        Zack Greinke  Diamondbacks
# 10      Ervin Santana         Twins
# 11    Carlos Carrasco       Indians
# 12      Drew Pomeranz       Red Sox
# 13   Justin Verlander        Astros
# 14     Andrew Cashner       Rangers
# 15         Lance Lynn     Cardinals
# 16       Jimmy Nelson       Brewers
# 17       Jake Arrieta          Cubs
# 18       Jacob deGrom          Mets
# 19         Aaron Nola      Phillies
# 20         Sonny Gray       Yankees
# 21    Carlos Martinez     Cardinals
# 22          Alex Cobb          Rays
# 23         Jose Urena       Marlins
# 24     Michael Fulmer        Tigers
# ...

# %%
real_stats = list(player_dict.values())

# %%
real_stats = real_stats[1:]
print(real_stats)
# Out:
# [['18', '4', '2.25', '29', '29', '5', '3', '0', '0', '0', '203.2', '777', '141', '56', '51', '21', '36', '2', '5', '4', '0', '265'], ['18', '4', '2.31', '27', '27', '1', '0', '0', '0', '0', '175.0', '679', '136', '49', '45', '23', '30', '0', '0', '4', '2', '202'], ['16', '6', '2.51', '31', '31', '2', '0', '0', '0', '0', '200.2', '780', '126', '62', '56', '22', '55', '2', '11', '4', '0', '268'], ['15', '4', '2.52', '28', '28', '1', '1', '0', '0', '0', '175.1', '701', '131', '55', '49', '13', '47', '5', '7', '3', '0', '204'], ['15', '5', '2.89', '28', '28', '1', '1', '0', '0', '0', '162.0', '665', '116', '57', '52', '23', '71', '3', '5', '8', '0', '218'], ['17', '8', '2.90', '32', '32', '1', '0', '0', '0', '0', '214.1', '851', '165', '73', '69', '24', '43', '0', '8', '3', '0', '308'], ['15', '9', '2.96', '32', '32', '0', '0', '0', '0', '0', '201.0', '827', '158', '69', '66', '21', '79', '5', '7', '7', '0', '188'], ['14', '6', '2.98', '31', '31', '0', '0', '0', '0', '0', '193.1', '783',
# ...

# %%
w_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[0]]
l_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[1]]
era_num = [float(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[2]]
g_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[3]]
gs_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[4]]
cg_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[5]]
sho_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[6]]
sv_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[7]]
hld_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[8]]
bs_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[9]]
ip_num = [float(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[10]]
tbf_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[11]]
h_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[12]]
r_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[13]]
er_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[14]]
hr_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[15]]
bb_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[16]]
ibb_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[17]]
hbp_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[18]]
wp_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[19]]
bk_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[20]]
so_num = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats))[21]]

# %%
temporary = pd.DataFrame({'W' : w_num, 'L' : l_num, 'ERA' : era_num, 'G' : g_num, 'GS' : gs_num, 'CG' : cg_num, 'ShO' : sho_num, 'SV' : sv_num, 'HLD' : hld_num, 'BS' : bs_num, 'IP' : ip_num, 'TBF' : tbf_num, 'H' : h_num, 'R' : r_num, 'ER' : er_num, 'HR' : hr_num, 'BB' : bb_num, 'IBB' : ibb_num, 'HBP' : hbp_num, 'WP' : wp_num, 'BK' : bk_num, 'SO' : so_num})

# %%
temporary
# Out:
#     BB  BK  BS  CG   ER   ERA   G  GS    H  HBP  HLD  HR  IBB     IP   L    R  \
# 0   36   0   0   5   51  2.25  29  29  141    5    0  21    2  203.2   4   56
# 1   30   2   0   1   45  2.31  27  27  136    0    0  23    0  175.0   4   49
# 2   55   0   0   2   56  2.51  31  31  126   11    0  22    2  200.2   6   62
# 3   47   0   0   1   49  2.52  28  28  131    7    0  13    5  175.1   4   55
# 4   71   0   0   1   52  2.89  28  28  116    5    0  23    3  162.0   5   57
# 5   43   0   0   1   69  2.90  32  32  165    8    0  24    0  214.1   8   73
# 6   79   0   0   0   66  2.96  32  32  158    7    0  21    5  201.0   9   69
# 7   51   0   0   0   64  2.98  31  31  150    6    0  21    0  193.1   6   73
# 8   62   1   0   2   69  3.09  33  33  201    6    0  21    1  201.0   9   82
# 9   45   0   0   1   72  3.20  32  32  172    0    0  25    0  202.1   7   80
# 10  61   1   0   5   77  3.28  33  33  177    8    0  31    2  211.1   8   85
# ...

# %%
asdasd = temporary.copy()

# %%
merged_data1 = pd.concat([name_team_list, asdasd], axis=1)
merged_data1
# Out:
#                  Name          Team  BB  BK  BS  CG   ER   ERA   G  GS    H  \
# 0        Corey Kluber       Indians  36   0   0   5   51  2.25  29  29  141
# 1     Clayton Kershaw       Dodgers  30   2   0   1   45  2.31  27  27  136
# 2        Max Scherzer     Nationals  55   0   0   2   56  2.51  31  31  126
# 3   Stephen Strasburg     Nationals  47   0   0   1   49  2.52  28  28  131
# 4          Robbie Ray  Diamondbacks  71   0   0   1   52  2.89  28  28  116
# 5          Chris Sale       Red Sox  43   0   0   1   69  2.90  32  32  165
# 6        Gio Gonzalez     Nationals  79   0   0   0   66  2.96  32  32  158
# 7       Luis Severino       Yankees  51   0   0   0   64  2.98  31  31  150
# 8      Marcus Stroman     Blue Jays  62   1   0   2   69  3.09  33  33  201
# 9        Zack Greinke  Diamondbacks  45   0   0   1   72  3.20  32  32  172
# 10      Ervin Santana         Twins  61   1   0   5   77  3.28  33  33  177
# ...

# %% [markdown]
# ## 2017 StanDard Stats. Page2

# %%
res = requests.get('http://www.fangraphs.com/leaders.aspx?pos=all&stats=pit&lg=all&qual=y&type=0&season=2017&month=0&season1=2017&ind=0&team=0&rost=0&age=0&filter=&players=0&page=2_50')
soup = BeautifulSoup(res.content, 'html.parser')

player_dict2 = {}
for player in soup.select('tbody > tr'):
    try:
        name = player.select('td > a')[0].text
    except:
        name = None
    try:
        team = player.select('td > a')[1].text
    except:
        team = None
    player_spec2 = []
    for i in player.select('td')[3:]:
        player_spec2.append(i.text)
    player_dict2[(name, team)] = player_spec2
print(len(player_dict2.keys()))
pprint(player_dict2)
# Out:
# 9
# {(None, None): [],
#  ('Clayton Richard', 'Padres'): ['8',
#                                  '15',
#                                  '4.79',
#                                  '32',
#                                  '32',
#                                  '2',
#                                  '1',
#                                  '0',
#                                  '0',
#                                  '0',
#                                  '197.1',
#                                  '858',
#                                  '240',
#                                  '114',
#                                  '105',
#                                  '24',
#                                  '59',
#                                  '6',
#                                  '8',
#                                  '7',
#                                  '1',
#                                  '151'],
#  ('Jason Hammel', 'Royals'): ['8',
# ...

# %%
key_list2 = list(player_dict2.keys())
key_list2 = key_list2[1:]
key_list2
# Out:
# [('Ty Blach', 'Giants'),
#  ('Clayton Richard', 'Padres'),
#  ('Martin Perez', 'Rangers'),
#  ('Ricky Nolasco', 'Angels'),
#  ('Marco Estrada', 'Blue Jays'),
#  ('Jason Hammel', 'Royals'),
#  ('Jeremy Hellickson', None),
#  ('Matt Moore', 'Giants')]

# %%
name_list2 = []
team_list2 = []

for i in range(len(key_list2)):
    name_list2.append(key_list2[i][0])

for i in range(len(key_list2)):
    team_list2.append(key_list2[i][1])
    

print(name_list2, '\n\n', team_list2)
# Out:
# ['Ty Blach', 'Clayton Richard', 'Martin Perez', 'Ricky Nolasco', 'Marco Estrada', 'Jason Hammel', 'Jeremy Hellickson', 'Matt Moore']
#
#  ['Giants', 'Padres', 'Rangers', 'Angels', 'Blue Jays', 'Royals', None, 'Giants']

# %%
name_list2 = pd.DataFrame({'Name' : name_list2})
team_list2 = pd.DataFrame({'Team' : team_list2})

name_list2.insert(1, 'Team', team_list2)
name_team_list2 = name_list2

# %%
print(len(name_team_list2))
name_team_list2
# Out:
# 8
#                 Name       Team
# 0           Ty Blach     Giants
# 1    Clayton Richard     Padres
# 2       Martin Perez    Rangers
# 3      Ricky Nolasco     Angels
# 4      Marco Estrada  Blue Jays
# 5       Jason Hammel     Royals
# 6  Jeremy Hellickson       None
# 7         Matt Moore     Giants

# %%
name_team_list2.loc[6, 'Team'] = 'Orioles'

name_team_list2
# Out:
#                 Name       Team
# 0           Ty Blach     Giants
# 1    Clayton Richard     Padres
# 2       Martin Perez    Rangers
# 3      Ricky Nolasco     Angels
# 4      Marco Estrada  Blue Jays
# 5       Jason Hammel     Royals
# 6  Jeremy Hellickson    Orioles
# 7         Matt Moore     Giants

# %%
real_stats2 = list(player_dict2.values())

# %%
real_stats2 = real_stats2[1:]
print(real_stats2)
# Out:
# [['8', '12', '4.78', '34', '24', '1', '1', '0', '0', '0', '163.2', '692', '179', '91', '87', '17', '43', '2', '1', '3', '0', '73'], ['8', '15', '4.79', '32', '32', '2', '1', '0', '0', '0', '197.1', '858', '240', '114', '105', '24', '59', '6', '8', '7', '1', '151'], ['13', '12', '4.82', '32', '32', '0', '0', '0', '0', '0', '185.0', '811', '221', '108', '99', '23', '63', '3', '6', '4', '0', '115'], ['6', '15', '4.92', '33', '33', '1', '1', '0', '0', '0', '181.0', '787', '205', '102', '99', '35', '58', '3', '3', '4', '0', '143'], ['10', '9', '4.98', '33', '33', '0', '0', '0', '0', '0', '186.0', '806', '186', '104', '103', '31', '71', '0', '2', '1', '0', '176'], ['8', '13', '5.29', '32', '32', '0', '0', '0', '0', '0', '180.1', '804', '209', '109', '106', '26', '48', '2', '9', '7', '1', '145'], ['8', '11', '5.43', '30', '30', '0', '0', '0', '0', '0', '164.0', '695', '160', '105', '99', '35', '47', '2', '8', '4', '1', '96'], ['6', '15', '5.52', '32', '31', '0', '0', '0', '0', '0', '174.1',
# ...

# %%
w_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[0]]
l_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[1]]
era_num2 = [float(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[2]]
g_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[3]]
gs_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[4]]
cg_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[5]]
sho_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[6]]
sv_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[7]]
hld_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[8]]
bs_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[9]]
ip_num2 = [float(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[10]]
tbf_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[11]]
h_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[12]]
r_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[13]]
er_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[14]]
hr_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[15]]
bb_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[16]]
ibb_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[17]]
hbp_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[18]]
wp_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[19]]
bk_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[20]]
so_num2 = [int(re.sub(r' %', '', x)) for x in list(zip(*real_stats2))[21]]

# %%
temporary2 = pd.DataFrame({'W' : w_num2, 'L' : l_num2, 'ERA' : era_num2, 'G' : g_num2, 'GS' : gs_num2, 'CG' : cg_num2, 'ShO' : sho_num2, 'SV' : sv_num2, 'HLD' : hld_num2, 'BS' : bs_num2, 'IP' : ip_num2, 'TBF' : tbf_num2, 'H' : h_num2, 'R' : r_num2, 'ER' : er_num2, 'HR' : hr_num2, 'BB' : bb_num2, 'IBB' : ibb_num2, 'HBP' : hbp_num2, 'WP' : wp_num2, 'BK' : bk_num2, 'SO' : so_num2})

# %%
temporary2
# Out:
#    BB  BK  BS  CG   ER   ERA   G  GS    H  HBP  HLD  HR  IBB     IP   L    R  \
# 0  43   0   0   1   87  4.78  34  24  179    1    0  17    2  163.2  12   91
# 1  59   1   0   2  105  4.79  32  32  240    8    0  24    6  197.1  15  114
# 2  63   0   0   0   99  4.82  32  32  221    6    0  23    3  185.0  12  108
# 3  58   0   0   1   99  4.92  33  33  205    3    0  35    3  181.0  15  102
# 4  71   0   0   0  103  4.98  33  33  186    2    0  31    0  186.0   9  104
# 5  48   1   0   0  106  5.29  32  32  209    9    0  26    2  180.1  13  109
# 6  47   1   0   0   99  5.43  30  30  160    8    0  35    2  164.0  11  105
# 7  67   0   0   0  107  5.52  32  31  200    7    0  27    3  174.1  15  116
#
#     SO  SV  ShO  TBF   W  WP
# 0   73   0    1  692   8   3
# 1  151   0    1  858   8   7
# 2  115   0    0  811  13   4
# 3  143   0    1  787   6   4
# 4  176   0    0  806  10   1
# 5  145   0    0  804   8   7
# 6   96   0    0  695   8   4
# 7  148   0    0  790   6  10

# %%
asdasd2 = temporary2.copy()

# %%
merged_data2 = pd.concat([name_team_list2, asdasd2], axis=1)
merged_data2
# Out:
#                 Name       Team  BB  BK  BS  CG   ER   ERA   G  GS    H  HBP  \
# 0           Ty Blach     Giants  43   0   0   1   87  4.78  34  24  179    1
# 1    Clayton Richard     Padres  59   1   0   2  105  4.79  32  32  240    8
# 2       Martin Perez    Rangers  63   0   0   0   99  4.82  32  32  221    6
# 3      Ricky Nolasco     Angels  58   0   0   1   99  4.92  33  33  205    3
# 4      Marco Estrada  Blue Jays  71   0   0   0  103  4.98  33  33  186    2
# 5       Jason Hammel     Royals  48   1   0   0  106  5.29  32  32  209    9
# 6  Jeremy Hellickson    Orioles  47   1   0   0   99  5.43  30  30  160    8
# 7         Matt Moore     Giants  67   0   0   0  107  5.52  32  31  200    7
#
#    HLD  HR  IBB     IP   L    R   SO  SV  ShO  TBF   W  WP
# 0    0  17    2  163.2  12   91   73   0    1  692   8   3
# 1    0  24    6  197.1  15  114  151   0    1  858   8   7
# 2    0  23    3  185.0  12  108  115   0    0  811  13   4
# ...

# %% [markdown]
# ## Merging 2017 StanDard P Data

# %%
merging_2017_std_p = pd.concat([merged_data1, merged_data2])
merging_2017_std_p = merging_2017_std_p.reset_index()

# %%
del merging_2017_std_p['index']

merging_2017_std_p.shape
# Out:
# (58, 24)

# %%
to_list = merging_2017_std_p.columns.tolist()
print(to_list)
# Out:
# ['Name', 'Team', 'BB', 'BK', 'BS', 'CG', 'ER', 'ERA', 'G', 'GS', 'H', 'HBP', 'HLD', 'HR', 'IBB', 'IP', 'L', 'R', 'SO', 'SV', 'ShO', 'TBF', 'W', 'WP']

# %%
to_list = ['Name', 'Team', 'W', 'L', 'G', 'GS', 'CG', 'IP', 'ERA', 'H', 'HR', 'BB', 'SO', 'R', 'SV', 'BS', 'BK', 'ER', 'HBP', 'HLD', 'IBB', 'ShO', 'TBF', 'WP']

merging_2017_std_p = merging_2017_std_p[to_list]
merging_2017_std_p = merging_2017_std_p.reset_index()

del merging_2017_std_p['index']

print(merging_2017_std_p.shape)
merging_2017_std_p
# Out:
# (58, 24)
#                  Name          Team   W   L   G  GS  CG     IP   ERA    H  HR  \
# 0        Corey Kluber       Indians  18   4  29  29   5  203.2  2.25  141  21
# 1     Clayton Kershaw       Dodgers  18   4  27  27   1  175.0  2.31  136  23
# 2        Max Scherzer     Nationals  16   6  31  31   2  200.2  2.51  126  22
# 3   Stephen Strasburg     Nationals  15   4  28  28   1  175.1  2.52  131  13
# 4          Robbie Ray  Diamondbacks  15   5  28  28   1  162.0  2.89  116  23
# 5          Chris Sale       Red Sox  17   8  32  32   1  214.1  2.90  165  24
# 6        Gio Gonzalez     Nationals  15   9  32  32   0  201.0  2.96  158  21
# 7       Luis Severino       Yankees  14   6  31  31   0  193.1  2.98  150  21
# 8      Marcus Stroman     Blue Jays  13   9  33  33   2  201.0  3.09  201  21
# 9        Zack Greinke  Diamondbacks  17   7  32  32   1  202.1  3.20  172  25
# 10      Ervin Santana         Twins  16   8  33  33   5  211.1  3.28  177  31
# ...

# %%
merging_2017_std_p.to_csv('../csv/Merging_2017_STD_Pichers.csv', index=None)
