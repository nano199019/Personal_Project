# %%
import pandas as pd
import numpy as np
import re

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
read_dash = pd.read_csv('../csv/2011/Merging_2011_DASH_bat.csv')
read_std = pd.read_csv('../csv/2011/Merging_2011_STD_bat.csv')
read_adv = pd.read_csv('../csv/2011/Merging_2011_ADV_bat.csv')
read_wpa = pd.read_csv('../csv/2011/Merging_2011_WPA_bat.csv')

# %%
rd = read_dash.copy()
rs = read_std.copy()
ra = read_adv.copy()
rw = read_wpa.copy()

# %%
merge1 = rd.merge(rs, how='inner')
merge2 = merge1.merge(ra, how='inner')
merge = merge2.merge(rw, how='inner')

# %%
to_list = merge.columns.tolist()

to_list = ['Name', 'Team', 'G', 'AB', 'PA', 'H', '1B', '2B', '3B', 'HR', 'R', 'RBI', 'BB', 'IBB', 'SO', 'BB%', 'K%', 'BB/K', 'BABIP', 'HBP', 'SF', 'SH', 'GDP', 'SB', 'CS', 'Def', 'ISO', 'wOBA', 'wRAA', 'AVG', 'OBP', 'SLG', 'OPS', 'WAR', 'wRC+', 'WPA']
merge = merge[to_list]

print(merge.shape)
# Out:
# (145, 36)

# %%
copy = merge.copy()

# %%
bb_list = list(copy['BB%'])
k_list = list(copy['K%'])

bb = [float(re.sub(r' %', '', x)) for x in list(bb_list)]
k = [float(re.sub(r' %', '', x)) for x in list(k_list)]

# %%
merge['BB%'] = bb
merge['K%'] = k

# %%
print(merge.shape)
merge
# Out:
# (145, 36)
#                     Name          Team    G   AB   PA    H   1B  2B  3B  HR  \
# 0        Jacoby Ellsbury       Red Sox  158  660  732  212  129  46   5  32
# 1              Matt Kemp       Dodgers  161  602  689  195  119  33   4  39
# 2          Jose Bautista     Blue Jays  149  513  655  155   86  24   2  43
# 3         Dustin Pedroia       Red Sox  159  635  731  195  134  37   3  21
# 4            Ian Kinsler       Rangers  155  620  723  158   88  34   4  32
# 5             Ryan Braun       Brewers  150  563  629  187  110  38   6  33
# 6      Curtis Granderson       Yankees  156  583  691  153   76  26  10  41
# 7            Alex Gordon        Royals  151  611  690  185  113  45   4  23
# 8         Miguel Cabrera        Tigers  161  572  688  197  119  48   0  30
# 9             Joey Votto          Reds  161  599  719  185  113  40   3  29
# 10           Ben Zobrist          Rays  156  588  674  158   86  46   6  20
# ...

# %%
merge.loc[31, 'Team'] = 'Phillies'
merge.loc[32, 'Team'] = 'Giants'
merge.loc[45, 'Team'] = 'Astros'
merge.loc[91, 'Team'] = 'Blue Jays'
merge.loc[114, 'Team'] = 'Dodgers'
merge.loc[120, 'Team'] = 'Blue Jays'
merge.loc[122, 'Team'] = 'Blue Jays'
merge.loc[125, 'Team'] = 'Dodgers'
merge.loc[126, 'Team'] = 'Reds'
merge.loc[137, 'Team'] = 'Tigers'
merge.loc[138, 'Team'] = 'Indians'

# %%
print(merge.shape)
merge
# Out:
# (145, 36)
#                     Name          Team    G   AB   PA    H   1B  2B  3B  HR  \
# 0        Jacoby Ellsbury       Red Sox  158  660  732  212  129  46   5  32
# 1              Matt Kemp       Dodgers  161  602  689  195  119  33   4  39
# 2          Jose Bautista     Blue Jays  149  513  655  155   86  24   2  43
# 3         Dustin Pedroia       Red Sox  159  635  731  195  134  37   3  21
# 4            Ian Kinsler       Rangers  155  620  723  158   88  34   4  32
# 5             Ryan Braun       Brewers  150  563  629  187  110  38   6  33
# 6      Curtis Granderson       Yankees  156  583  691  153   76  26  10  41
# 7            Alex Gordon        Royals  151  611  690  185  113  45   4  23
# 8         Miguel Cabrera        Tigers  161  572  688  197  119  48   0  30
# 9             Joey Votto          Reds  161  599  719  185  113  40   3  29
# 10           Ben Zobrist          Rays  156  588  674  158   86  46   6  20
# ...

# %%
merge.dtypes
# Out:
# Name      object
# Team      object
# G          int64
# AB         int64
# PA         int64
# H          int64
# 1B         int64
# 2B         int64
# 3B         int64
# HR         int64
# R          int64
# RBI        int64
# BB         int64
# IBB        int64
# SO         int64
# BB%      float64
# K%       float64
# BB/K     float64
# BABIP    float64
# HBP        int64
# SF         int64
# SH         int64
# GDP        int64
# SB         int64
# CS         int64
# Def      float64
# ISO      float64
# wOBA     float64
# wRAA     float64
# AVG      float64
# OBP      float64
# SLG      float64
# OPS      float64
# WAR      float64
# wRC+       int64
# WPA      float64
# dtype: object

# %%
merge.to_csv('../csv/2011/2011_Merging_batters_stats.csv', index=None)
