# %%
import pandas as pd
import numpy as np
import re

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
read_dash = pd.read_csv('../csv/2008/Merging_2008_DASH_bat.csv')
read_std = pd.read_csv('../csv/2008/Merging_2008_STD_bat.csv')
read_adv = pd.read_csv('../csv/2008/Merging_2008_ADV_bat.csv')
read_wpa = pd.read_csv('../csv/2008/Merging_2008_WPA_bat.csv')

# %%
rd = read_dash.copy()
rs = read_std.copy()
ra = read_adv.copy()
rw = read_wpa.copy()

# %%
merge1 = rd.merge(rs, how='inner')
merge2 = merge1.merge(ra, how='inner')
merge = merge2.merge(rw, how='inner')

# %%
to_list = merge.columns.tolist()

to_list = ['Name', 'Team', 'G', 'AB', 'PA', 'H', '1B', '2B', '3B', 'HR', 'R', 'RBI', 'BB', 'IBB', 'SO', 'BB%', 'K%', 'BB/K', 'BABIP', 'HBP', 'SF', 'SH', 'GDP', 'SB', 'CS', 'Def', 'ISO', 'wOBA', 'wRAA', 'AVG', 'OBP', 'SLG', 'OPS', 'WAR', 'wRC+', 'WPA']
merge = merge[to_list]

print(merge.shape)
# Out:
# (147, 36)

# %%
copy = merge.copy()

# %%
bb_list = list(copy['BB%'])
k_list = list(copy['K%'])

bb = [float(re.sub(r' %', '', x)) for x in list(bb_list)]
k = [float(re.sub(r' %', '', x)) for x in list(k_list)]

# %%
merge['BB%'] = bb
merge['K%'] = k

# %%
print(merge.shape)
merge
# Out:
# (147, 36)
#                     Name          Team    G   AB   PA    H   1B  2B  3B  HR  \
# 0          Albert Pujols     Cardinals  148  524  641  187  106  44   0  37
# 1            Chase Utley      Phillies  159  607  707  177   99  41   4  33
# 2          Lance Berkman        Astros  159  554  665  173   94  46   4  29
# 3         Hanley Ramirez       Marlins  153  589  693  177  106  34   4  33
# 4         Grady Sizemore       Indians  157  634  745  170   93  39   5  33
# 5         Carlos Beltran          Mets  161  606  706  172  100  40   5  27
# 6          Chipper Jones        Braves  128  439  534  160  113  24   1  22
# 7           David Wright          Mets  160  626  736  189  112  42   2  33
# 8          Mark Teixeira         - - -  157  574  685  177  103  41   0  33
# 9         Dustin Pedroia       Red Sox  157  653  726  213  140  54   2  17
# 10        Kevin Youkilis       Red Sox  145  538  621  168   92  43   4  29
# ...

# %%
merge.loc[8, 'Team'] = 'Angels'
merge.loc[12, 'Team'] = 'Dodgers'
merge.loc[60, 'Team'] = 'Yankees'
merge.loc[63, 'Team'] = 'Red Sox'
merge.loc[91, 'Team'] = 'Dodgers'
merge.loc[121, 'Team'] = 'Braves'
merge.loc[125, 'Team'] = 'Diamondbacks'
merge.loc[128, 'Team'] = 'Cardinals'
merge.loc[141, 'Team'] = 'White Sox'

# %%
print(merge.shape)
merge
# Out:
# (147, 36)
#                     Name          Team    G   AB   PA    H   1B  2B  3B  HR  \
# 0          Albert Pujols     Cardinals  148  524  641  187  106  44   0  37
# 1            Chase Utley      Phillies  159  607  707  177   99  41   4  33
# 2          Lance Berkman        Astros  159  554  665  173   94  46   4  29
# 3         Hanley Ramirez       Marlins  153  589  693  177  106  34   4  33
# 4         Grady Sizemore       Indians  157  634  745  170   93  39   5  33
# 5         Carlos Beltran          Mets  161  606  706  172  100  40   5  27
# 6          Chipper Jones        Braves  128  439  534  160  113  24   1  22
# 7           David Wright          Mets  160  626  736  189  112  42   2  33
# 8          Mark Teixeira        Angels  157  574  685  177  103  41   0  33
# 9         Dustin Pedroia       Red Sox  157  653  726  213  140  54   2  17
# 10        Kevin Youkilis       Red Sox  145  538  621  168   92  43   4  29
# ...

# %%
merge.dtypes
# Out:
# Name      object
# Team      object
# G          int64
# AB         int64
# PA         int64
# H          int64
# 1B         int64
# 2B         int64
# 3B         int64
# HR         int64
# R          int64
# RBI        int64
# BB         int64
# IBB        int64
# SO         int64
# BB%      float64
# K%       float64
# BB/K     float64
# BABIP    float64
# HBP        int64
# SF         int64
# SH         int64
# GDP        int64
# SB         int64
# CS         int64
# Def      float64
# ISO      float64
# wOBA     float64
# wRAA     float64
# AVG      float64
# OBP      float64
# SLG      float64
# OPS      float64
# WAR      float64
# wRC+       int64
# WPA      float64
# dtype: object

# %%
merge.to_csv('../csv/2008/2008_Merging_batters_stats.csv', index=None)
