# %%
import pandas as pd
import numpy as np
import re

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
read_dash = pd.read_csv('../csv/2015/Merging_2015_DASH_pitchers.csv')
read_std = pd.read_csv('../csv/2015/Merging_2015_STD_pitchers.csv')
read_adv = pd.read_csv('../csv/2015/Merging_2015_ADV_pitchers.csv')
read_wpa = pd.read_csv('../csv/2015/Merging_2015_WPA_pitchers.csv')

# %%
rd = read_dash.copy()
rs = read_std.copy()
ra = read_adv.copy()
rw = read_wpa.copy()

# %%
merge1 = rd.merge(rs, how='inner')
merge2 = merge1.merge(ra, how='inner')
merge = merge2.merge(rw, how='inner')

print(merge.shape)
merge
# Out:
# (78, 60)
#                   Name          Team   W   L  SV   G  GS     IP    K/9  BB/9  \
# 0      Clayton Kershaw       Dodgers  16   7   0  33  33  232.2  11.64  1.62
# 1         Jake Arrieta          Cubs  22   6   0  33  33  229.0   9.28  1.89
# 2          David Price         - - -  18   5   0  32  32  220.1   9.19  1.92
# 3         Max Scherzer     Nationals  14  12   0  33  33  228.2  10.86  1.34
# 4           Chris Sale     White Sox  13  11   0  31  31  208.2  11.82  1.81
# 5       Dallas Keuchel        Astros  20   8   0  33  33  232.0   8.38  1.98
# 6         Zack Greinke       Dodgers  19   3   0  32  32  222.2   8.08  1.62
# 7         Corey Kluber       Indians   9  16   0  32  32  222.0   9.93  1.82
# 8          Gerrit Cole       Pirates  19   8   0  32  32  208.0   8.74  1.90
# 9         Chris Archer          Rays  12  13   0  34  34  212.0  10.70  2.80
# 10   Madison Bumgarner        Giants  18   9   0  32  32  218.1   9.65  1.61
# ...

# %%
to_list = merge.columns.tolist()

to_list = ['Name', 'Team', 'W', 'L', 'G', 'GS', 'CG', 'IP', 'H', 'HR', 'BB', 'SO', 'R', 'SV', 'BS', 'BK', 'ER', 'HBP', 'HLD', 'IBB', 'ShO', 'TBF', 'WP', 'HR/9', 'BB/9', 'K/9', 'K/BB', 'K-BB%', 'GB%', 'HR/FB', 'LOB%', 'ERA', 'BABIP', 'FIP', 'WHIP', 'WPA', 'WAR']
merge = merge[to_list]

print(merge.shape)
merge
# Out:
# (78, 37)
#                   Name          Team   W   L   G  GS  CG     IP    H  HR  BB  \
# 0      Clayton Kershaw       Dodgers  16   7  33  33   4  232.2  163  15  42
# 1         Jake Arrieta          Cubs  22   6  33  33   4  229.0  150  10  48
# 2          David Price         - - -  18   5  32  32   3  220.1  190  17  47
# 3         Max Scherzer     Nationals  14  12  33  33   4  228.2  176  27  34
# 4           Chris Sale     White Sox  13  11  31  31   1  208.2  185  23  42
# 5       Dallas Keuchel        Astros  20   8  33  33   3  232.0  185  17  51
# 6         Zack Greinke       Dodgers  19   3  32  32   1  222.2  148  14  40
# 7         Corey Kluber       Indians   9  16  32  32   4  222.0  189  22  45
# 8          Gerrit Cole       Pirates  19   8  32  32   0  208.0  183  11  44
# 9         Chris Archer          Rays  12  13  34  34   1  212.0  175  19  66
# 10   Madison Bumgarner        Giants  18   9  32  32   4  218.1  181  21  39
# ...

# %%
copy = merge.copy()

# %%
k_bb_list = merge['K-BB%']
gb_list = merge['GB%']
hr_fb_list = merge['HR/FB']
lob_list = merge['LOB%']

# %%
k_bb = [float(re.sub(r' %', '', x)) for x in list(k_bb_list)]
gb = [float(re.sub(r' %', '', x)) for x in list(gb_list)]
hr_fb = [float(re.sub(r' %', '', x)) for x in list(hr_fb_list)]
lob = [float(re.sub(r' %', '', x)) for x in list(lob_list)]

# %%
merge['K-BB%'] = k_bb
merge['GB%'] = gb
merge['HR/FB'] = hr_fb
merge['LOB%'] = lob

print(merge.shape)
merge
# Out:
# (78, 37)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
merge.loc[2, 'Team'] = 'Tigers'
merge.loc[17, 'Team'] = 'Rangers'
merge.loc[18, 'Team'] = 'Reds'
merge.loc[25, 'Team'] = 'Pirates'
merge.loc[41, 'Team'] = 'Dodgers'
merge.loc[47, 'Team'] = 'Astros'
merge.loc[50, 'Team'] = 'Astros'
merge.loc[63, 'Team'] = 'Giants'
merge.loc[71, 'Team'] = 'Cubs'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
print(merge.shape)
merge
# Out:
# (78, 37)
#                   Name          Team   W   L   G  GS  CG     IP    H  HR  BB  \
# 0      Clayton Kershaw       Dodgers  16   7  33  33   4  232.2  163  15  42
# 1         Jake Arrieta          Cubs  22   6  33  33   4  229.0  150  10  48
# 2          David Price        Tigers  18   5  32  32   3  220.1  190  17  47
# 3         Max Scherzer     Nationals  14  12  33  33   4  228.2  176  27  34
# 4           Chris Sale     White Sox  13  11  31  31   1  208.2  185  23  42
# 5       Dallas Keuchel        Astros  20   8  33  33   3  232.0  185  17  51
# 6         Zack Greinke       Dodgers  19   3  32  32   1  222.2  148  14  40
# 7         Corey Kluber       Indians   9  16  32  32   4  222.0  189  22  45
# 8          Gerrit Cole       Pirates  19   8  32  32   0  208.0  183  11  44
# 9         Chris Archer          Rays  12  13  34  34   1  212.0  175  19  66
# 10   Madison Bumgarner        Giants  18   9  32  32   4  218.1  181  21  39
# ...

# %%
merge.dtypes
# Out:
# Name      object
# Team      object
# W          int64
# L          int64
# G          int64
# GS         int64
# CG         int64
# IP       float64
# H          int64
# HR         int64
# BB         int64
# SO         int64
# R          int64
# SV         int64
# BS         int64
# BK         int64
# ER         int64
# HBP        int64
# HLD        int64
# IBB        int64
# ShO        int64
# TBF        int64
# WP         int64
# HR/9     float64
# BB/9     float64
# K/9      float64
# K/BB     float64
# K-BB%    float64
# GB%      float64
# HR/FB    float64
# LOB%     float64
# ERA      float64
# BABIP    float64
# FIP      float64
# WHIP     float64
# WPA      float64
# WAR      float64
# dtype: object

# %%
merge.to_csv('../csv/2015/2015_Merging_pitchers_stats.csv', index=None)
