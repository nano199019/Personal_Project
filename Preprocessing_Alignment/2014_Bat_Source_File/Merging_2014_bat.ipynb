# %%
import pandas as pd
import numpy as np
import re

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
read_dash = pd.read_csv('../csv/2014/Merging_2014_DASH_bat.csv')
read_std = pd.read_csv('../csv/2014/Merging_2014_STD_bat.csv')
read_adv = pd.read_csv('../csv/2014/Merging_2014_ADV_bat.csv')
read_wpa = pd.read_csv('../csv/2014/Merging_2014_WPA_bat.csv')

# %%
rd = read_dash.copy()
rs = read_std.copy()
ra = read_adv.copy()
rw = read_wpa.copy()

# %%
merge1 = rd.merge(rs, how='inner')
merge2 = merge1.merge(ra, how='inner')
merge = merge2.merge(rw, how='inner')

print(merge.shape)
merge
# Out:
# (146, 53)
#                    Name          Team    G   PA  HR    R  RBI  SB     BB%  \
# 0            Mike Trout        Angels  157  705  36  115  111  16  11.8 %
# 1      Andrew McCutchen       Pirates  146  648  25   89   83  18  13.0 %
# 2        Josh Donaldson     Athletics  158  695  29   93   98   8  10.9 %
# 3        Anthony Rendon     Nationals  153  683  21  111   83  17   8.5 %
# 4           Alex Gordon        Royals  156  643  19   87   74  12  10.1 %
# 5         Jose Bautista     Blue Jays  155  673  35  101  103   6  15.5 %
# 6     Giancarlo Stanton       Marlins  145  638  37   89  105  13  14.7 %
# 7       Jonathan Lucroy       Brewers  153  655  13   73   69   4  10.1 %
# 8      Michael Brantley       Indians  156  676  20   94   97  23   7.7 %
# 9         Adrian Beltre       Rangers  148  614  19   79   77   1   9.3 %
# 10        Anthony Rizzo          Cubs  140  616  32   89   78   5  11.9 %
# ...

# %%
to_list = merge.columns.tolist()

to_list = ['Name', 'Team', 'G', 'AB', 'PA', 'H', '1B', '2B', '3B', 'HR', 'R', 'RBI', 'BB', 'IBB', 'SO', 'BB%', 'K%', 'BB/K', 'BABIP', 'HBP', 'SF', 'SH', 'GDP', 'SB', 'CS', 'Def', 'ISO', 'wOBA', 'wRAA', 'AVG', 'OBP', 'SLG', 'OPS', 'WAR', 'wRC+', 'WPA']
merge = merge[to_list]

print(merge.shape)
merge
# Out:
# (146, 36)
#                    Name          Team    G   AB   PA    H   1B  2B  3B  HR  \
# 0            Mike Trout        Angels  157  602  705  173   89  39   9  36
# 1      Andrew McCutchen       Pirates  146  548  648  172  103  38   6  25
# 2        Josh Donaldson     Athletics  158  608  695  155   93  31   2  29
# 3        Anthony Rendon     Nationals  153  613  683  176  110  39   6  21
# 4           Alex Gordon        Royals  156  563  643  150   96  34   1  19
# 5         Jose Bautista     Blue Jays  155  553  673  158   96  27   0  35
# 6     Giancarlo Stanton       Marlins  145  539  638  155   86  31   1  37
# 7       Jonathan Lucroy       Brewers  153  585  655  176  108  53   2  13
# 8      Michael Brantley       Indians  156  611  676  200  133  45   2  20
# 9         Adrian Beltre       Rangers  148  549  614  178  125  33   1  19
# 10        Anthony Rizzo          Cubs  140  524  616  150   89  28   1  32
# ...

# %%
copy = merge.copy()

# %%
bb_list = list(copy['BB%'])
k_list = list(copy['K%'])

bb = [float(re.sub(r' %', '', x)) for x in list(bb_list)]
k = [float(re.sub(r' %', '', x)) for x in list(k_list)]

# %%
merge['BB%'] = bb
merge['K%'] = k

merge
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                    Name          Team    G   AB   PA    H   1B  2B  3B  HR  \
# 0            Mike Trout        Angels  157  602  705  173   89  39   9  36
# 1      Andrew McCutchen       Pirates  146  548  648  172  103  38   6  25
# ...

# %%
merge.loc[36, 'Team'] = 'Padres'
merge.loc[58, 'Team'] = 'Red Sox'
merge.loc[81, 'Team'] = 'Yankees'
merge.loc[100, 'Team'] = 'Orioles'
merge.loc[102, 'Team'] = 'Nationals'
merge.loc[104, 'Team'] = 'Padres'
merge.loc[116, 'Team'] = 'Mariners'
merge.loc[123, 'Team'] = 'Athletics'
merge.loc[131, 'Team'] = 'Brewers'
merge.loc[144, 'Team'] = 'Red Sox'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
print(merge.shape)
merge
# Out:
# (146, 36)
#                    Name          Team    G   AB   PA    H   1B  2B  3B  HR  \
# 0            Mike Trout        Angels  157  602  705  173   89  39   9  36
# 1      Andrew McCutchen       Pirates  146  548  648  172  103  38   6  25
# 2        Josh Donaldson     Athletics  158  608  695  155   93  31   2  29
# 3        Anthony Rendon     Nationals  153  613  683  176  110  39   6  21
# 4           Alex Gordon        Royals  156  563  643  150   96  34   1  19
# 5         Jose Bautista     Blue Jays  155  553  673  158   96  27   0  35
# 6     Giancarlo Stanton       Marlins  145  539  638  155   86  31   1  37
# 7       Jonathan Lucroy       Brewers  153  585  655  176  108  53   2  13
# 8      Michael Brantley       Indians  156  611  676  200  133  45   2  20
# 9         Adrian Beltre       Rangers  148  549  614  178  125  33   1  19
# 10        Anthony Rizzo          Cubs  140  524  616  150   89  28   1  32
# ...

# %%
merge.dtypes
# Out:
# Name      object
# Team      object
# G          int64
# AB         int64
# PA         int64
# H          int64
# 1B         int64
# 2B         int64
# 3B         int64
# HR         int64
# R          int64
# RBI        int64
# BB         int64
# IBB        int64
# SO         int64
# BB%      float64
# K%       float64
# BB/K     float64
# BABIP    float64
# HBP        int64
# SF         int64
# SH         int64
# GDP        int64
# SB         int64
# CS         int64
# Def      float64
# ISO      float64
# wOBA     float64
# wRAA     float64
# AVG      float64
# OBP      float64
# SLG      float64
# OPS      float64
# WAR      float64
# wRC+       int64
# WPA      float64
# dtype: object

# %%
merge.to_csv('../csv/2014/2014_Merging_batters_stats.csv', index=None)
