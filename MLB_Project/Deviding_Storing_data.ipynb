# %%
import pandas as pd
import numpy as np

# %%
b_read_06 = pd.read_csv('../../Personal_Project/Source_File/Deviding_B_P_csv/Batters/fa_2006_bat_list.csv')
b_read_07 = pd.read_csv('../../Personal_Project/Source_File/Deviding_B_P_csv/Batters/fa_2007_bat_list.csv')
b_read_08 = pd.read_csv('../../Personal_Project/Source_File/Deviding_B_P_csv/Batters/fa_2008_bat_list.csv')
b_read_09 = pd.read_csv('../../Personal_Project/Source_File/Deviding_B_P_csv/Batters/fa_2009_bat_list.csv')
b_read_10 = pd.read_csv('../../Personal_Project/Source_File/Deviding_B_P_csv/Batters/fa_2010_bat_list.csv')
b_read_11 = pd.read_csv('../../Personal_Project/Source_File/Deviding_B_P_csv/Batters/fa_2011_bat_list.csv')
b_read_12 = pd.read_csv('../../Personal_Project/Source_File/Deviding_B_P_csv/Batters/fa_2012_bat_list.csv')
b_read_13 = pd.read_csv('../../Personal_Project/Source_File/Deviding_B_P_csv/Batters/fa_2013_bat_list.csv')
b_read_14 = pd.read_csv('../../Personal_Project/Source_File/Deviding_B_P_csv/Batters/fa_2014_bat_list.csv')
b_read_15 = pd.read_csv('../../Personal_Project/Source_File/Deviding_B_P_csv/Batters/fa_2015_bat_list.csv')
b_read_16 = pd.read_csv('../../Personal_Project/Source_File/Deviding_B_P_csv/Batters/fa_2016_bat_list.csv')
b_read_17 = pd.read_csv('../../Personal_Project/Source_File/Deviding_B_P_csv/Batters/fa_2017_bat_list.csv')

# %%
p_read_06 = pd.read_csv('../../Personal_Project/Source_File/Deviding_B_P_csv/Pitchers/fa_2006_pit_list.csv')
p_read_07 = pd.read_csv('../../Personal_Project/Source_File/Deviding_B_P_csv/Pitchers/fa_2007_pit_list.csv')
p_read_08 = pd.read_csv('../../Personal_Project/Source_File/Deviding_B_P_csv/Pitchers/fa_2008_pit_list.csv')
p_read_09 = pd.read_csv('../../Personal_Project/Source_File/Deviding_B_P_csv/Pitchers/fa_2009_pit_list.csv')
p_read_10 = pd.read_csv('../../Personal_Project/Source_File/Deviding_B_P_csv/Pitchers/fa_2010_pit_list.csv')
p_read_11 = pd.read_csv('../../Personal_Project/Source_File/Deviding_B_P_csv/Pitchers/fa_2011_pit_list.csv')
p_read_12 = pd.read_csv('../../Personal_Project/Source_File/Deviding_B_P_csv/Pitchers/fa_2012_pit_list.csv')
p_read_13 = pd.read_csv('../../Personal_Project/Source_File/Deviding_B_P_csv/Pitchers/fa_2013_pit_list.csv')
p_read_14 = pd.read_csv('../../Personal_Project/Source_File/Deviding_B_P_csv/Pitchers/fa_2014_pit_list.csv')
p_read_15 = pd.read_csv('../../Personal_Project/Source_File/Deviding_B_P_csv/Pitchers/fa_2015_pit_list.csv')
p_read_16 = pd.read_csv('../../Personal_Project/Source_File/Deviding_B_P_csv/Pitchers/fa_2016_pit_list.csv')
p_read_17 = pd.read_csv('../../Personal_Project/Source_File/Deviding_B_P_csv/Pitchers/fa_2017_pit_list.csv')

# %%
b_merge1 = pd.concat([b_read_06, b_read_07])
b_merge2 = pd.concat([b_merge1, b_read_08])
b_merge3 = pd.concat([b_merge2, b_read_09])
b_merge4 = pd.concat([b_merge3, b_read_10])
b_merge5 = pd.concat([b_merge4, b_read_11])
b_merge6 = pd.concat([b_merge5, b_read_12])
b_merge7 = pd.concat([b_merge6, b_read_13])
b_merge8 = pd.concat([b_merge7, b_read_14])
b_merge9 = pd.concat([b_merge8, b_read_15])
b_merge10 = pd.concat([b_merge9, b_read_16])
b_merge = pd.concat([b_merge10, b_read_17])

# %%
p_merge1 = pd.concat([p_read_06, p_read_07])
p_merge2 = pd.concat([p_merge1, p_read_08])
p_merge3 = pd.concat([p_merge2, p_read_09])
p_merge4 = pd.concat([p_merge3, p_read_10])
p_merge5 = pd.concat([p_merge4, p_read_11])
p_merge6 = pd.concat([p_merge5, p_read_12])
p_merge7 = pd.concat([p_merge6, p_read_13])
p_merge8 = pd.concat([p_merge7, p_read_14])
p_merge9 = pd.concat([p_merge8, p_read_15])
p_merge10 = pd.concat([p_merge9, p_read_16])
p_merge = pd.concat([p_merge10, p_read_17])

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

b_merge_1 = b_merge.set_index('Name', inplace=False)
b_merge_2 = b_merge_1.reset_index()

B_merged = b_merge_2

# %%
p_merge_1 = p_merge.set_index('Name', inplace=False)
p_merge_2 = p_merge_1.reset_index()

P_merged = p_merge_2

# %%
print(B_merged.shape)
B_merged
# Out:
# (633, 40)
#                       Name    Yr          Team    G   AB   PA    H   1B  2B  \
# 0              Aaron Boone  2006       Indians  104  354  392   89   62  19
# 1             Adam Kennedy  2006        Angels  139  451  503  123   87  26
# 2                Alex Cora  2006       Red Sox   96  235  264   56   46   7
# 3            Alex Gonzalez  2006       Red Sox  111  388  429   99   64  24
# 4          Alfonso Soriano  2006     Nationals  159  647  728  179   90  41
# 5            Andy Pettitte  2006        Astros   38   62   73   12    8   3
# 6           Aramis Ramirez  2006          Cubs  157  594  660  173   93  38
# 7              Aubrey Huff  2006       Orioles  131  454  517  121   73  25
# 8              Barry Bonds  2006        Giants  130  367  493   99   50  23
# 9            Bengie Molina  2006     Blue Jays  117  433  458  123   83  20
# 10              Carlos Lee  2006        Astros  161  624  695  187  112  37
# ...

# %%
to_list = P_merged.columns.tolist()
to_list = ['Name', 'Yr', 'Team', 'W', 'L', 'G', 'GS', 'CG', 'IP', 'H', 'HR', 'BB', 'SO', 'R', 'SV', 'BS', 'BK', 'ER', 'HBP', 'HLD', 'IBB', 'ShO', 'TBF', 'WP', 'HR/9', 'BB/9', 'K/9', 'K/BB', 'K-BB%', 'GB%', 'HR/FB', 'LOB%', 'ERA', 'BABIP', 'FIP', 'WHIP','WPA', 'WAR', 'Contract Yrs', 'Total Salary($)', 'Avg Salary($)']
P_merged = P_merged[to_list]

print(P_merged.shape)
P_merged
# Out:
# (588, 41)
#                     Name    Yr          Team   W   L   G  GS  CG     IP    H  \
# 0            Aaron Fultz  2006      Phillies   3   1  66   1   0   71.1   80
# 1             Adam Eaton  2006       Rangers   7   4  13  13   0   65.0   78
# 2            Alan Embree  2006        Padres   4   3  73   0   0   52.1   50
# 3          Andy Pettitte  2006        Astros  14  13  36  35   2  214.1  238
# 4             Barry Zito  2006     Athletics  16  10  34  34   0  221.0  211
# 5          Chad Bradford  2006          Mets   4   2  70   0   0   62.0   59
# 6           Chan Ho Park  2006        Padres   7   7  24  21   1  136.2  146
# 7          Chris Reitsma  2006        Braves   1   2  27   0   0   28.0   46
# 8             Danys Baez  2006       Orioles   5   6  57   0   0   59.2   60
# 9          Darren Oliver  2006          Mets   4   1  45   0   0   81.0   70
# 10           David Riske  2006        Royals   1   2  41   0   0   44.0   40
# ...

# %%
print(B_merged.isnull().sum(), '\n\n')
print(P_merged.isnull().sum())
# Out:
# Name               0
# Yr                 0
# Team               0
# G                  0
# AB                 0
# PA                 0
# H                  0
# 1B                 0
# 2B                 0
# 3B                 0
# HR                 0
# R                  0
# RBI                0
# BB                 0
# IBB                0
# SO                 0
# BB%                0
# K%                 0
# BB/K               0
# BABIP              0
# HBP                0
# SF                 0
# SH                 0
# GDP                0
# SB                 0
# CS                 0
# Def                0
# ISO                0
# wOBA               0
# wRAA               0
# AVG                0
# OBP                0
# SLG                0
# OPS                0
# WAR                0
# wRC+               0
# WPA                0
# Contract Yrs       0
# Total Salary($)    0
# Avg Salary($)      0
# dtype: int64
#
#
# Name               0
# Yr                 0
# ...

# %%
B_merged.to_csv('../../Project/csv/mlb_fa_bat_list.csv', index=None)
P_merged.to_csv('../../Project/csv/mlb_fa_pit_list.csv', index=None)
