# %%
import pandas as pd
import numpy as np
import re

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
read_dash = pd.read_csv('../csv/2012/Merging_2012_DASH_pitcher.csv')
read_std = pd.read_csv('../csv/2012/Merging_2012_STD_pitcher.csv')
read_adv = pd.read_csv('../csv/2012/Merging_2012_ADV_pitcher.csv')
read_wpa = pd.read_csv('../csv/2012/Merging_2012_WPA_pitcher.csv')

# %%
rd = read_dash.copy()
rs = read_std.copy()
ra = read_adv.copy()
rw = read_wpa.copy()

# %%
merge1 = rd.merge(rs, how='inner')
merge2 = merge1.merge(ra, how='inner')
merge = merge2.merge(rw, how='inner')

# %%
to_list = merge.columns.tolist()

to_list = ['Name', 'Team', 'W', 'L', 'G', 'GS', 'CG', 'IP', 'H', 'HR', 'BB', 'SO', 'R', 'SV', 'BS', 'BK', 'ER', 'HBP', 'HLD', 'IBB', 'ShO', 'TBF', 'WP', 'HR/9', 'BB/9', 'K/9', 'K/BB', 'K-BB%', 'GB%', 'HR/FB', 'LOB%', 'ERA', 'BABIP', 'FIP', 'WHIP', 'WPA', 'WAR']
merge = merge[to_list]

print(merge.shape)
merge
# Out:
# (88, 37)
#                  Name          Team   W   L   G  GS  CG     IP    H  HR   BB  \
# 0    Justin Verlander        Tigers  17   8  33  33   6  238.1  192  19   60
# 1     Felix Hernandez      Mariners  13   9  33  33   5  232.0  209  14   56
# 2     Clayton Kershaw       Dodgers  14   9  33  33   2  227.2  170  16   63
# 3         David Price          Rays  20   5  31  31   2  211.0  173  16   59
# 4           Cliff Lee      Phillies   6   9  30  30   0  211.0  207  26   28
# 5         R.A. Dickey          Mets  20   6  34  33   5  233.2  192  24   54
# 6        Gio Gonzalez     Nationals  21   8  32  32   2  199.1  149   9   76
# 7        Zack Greinke         - - -  15   5  34  34   0  212.1  200  18   54
# 8          Chris Sale     White Sox  17   8  30  29   1  192.0  167  19   51
# 9        Johnny Cueto          Reds  19   9  33  33   2  217.0  205  15   49
# 10        CC Sabathia       Yankees  15   6  28  28   2  200.0  184  22   44
# ...

# %%
copy = merge.copy()

# %%
k_bb_list = merge['K-BB%']
gb_list = merge['GB%']
hr_fb_list = merge['HR/FB']
lob_list = merge['LOB%']

# %%
k_bb = [float(re.sub(r' %', '', x)) for x in list(k_bb_list)]
gb = [float(re.sub(r' %', '', x)) for x in list(gb_list)]
hr_fb = [float(re.sub(r' %', '', x)) for x in list(hr_fb_list)]
lob = [float(re.sub(r' %', '', x)) for x in list(lob_list)]

# %%
merge['K-BB%'] = k_bb
merge['GB%'] = gb
merge['HR/FB'] = hr_fb
merge['LOB%'] = lob

# %%
print(merge.shape)
merge
# Out:
# (88, 37)
#                  Name          Team   W   L   G  GS  CG     IP    H  HR   BB  \
# 0    Justin Verlander        Tigers  17   8  33  33   6  238.1  192  19   60
# 1     Felix Hernandez      Mariners  13   9  33  33   5  232.0  209  14   56
# 2     Clayton Kershaw       Dodgers  14   9  33  33   2  227.2  170  16   63
# 3         David Price          Rays  20   5  31  31   2  211.0  173  16   59
# 4           Cliff Lee      Phillies   6   9  30  30   0  211.0  207  26   28
# 5         R.A. Dickey          Mets  20   6  34  33   5  233.2  192  24   54
# 6        Gio Gonzalez     Nationals  21   8  32  32   2  199.1  149   9   76
# 7        Zack Greinke         - - -  15   5  34  34   0  212.1  200  18   54
# 8          Chris Sale     White Sox  17   8  30  29   1  192.0  167  19   51
# 9        Johnny Cueto          Reds  19   9  33  33   2  217.0  205  15   49
# 10        CC Sabathia       Yankees  15   6  28  28   2  200.0  184  22   44
# ...

# %%
merge.loc[7, 'Team'] = 'Dodgers'
merge.loc[22, 'Team'] = 'Tigers'
merge.loc[31, 'Team'] = 'Rangers'
merge.loc[46, 'Team'] = 'Pirates'
merge.loc[47, 'Team'] = 'Dodgers'
merge.loc[55, 'Team'] = 'Orioles'
merge.loc[59, 'Team'] = 'Dodgers'
merge.loc[60, 'Team'] = 'Braves'
merge.loc[81, 'Team'] = 'Royals'

# %%
print(merge.shape)
merge
# Out:
# (88, 37)
#                  Name          Team   W   L   G  GS  CG     IP    H  HR   BB  \
# 0    Justin Verlander        Tigers  17   8  33  33   6  238.1  192  19   60
# 1     Felix Hernandez      Mariners  13   9  33  33   5  232.0  209  14   56
# 2     Clayton Kershaw       Dodgers  14   9  33  33   2  227.2  170  16   63
# 3         David Price          Rays  20   5  31  31   2  211.0  173  16   59
# 4           Cliff Lee      Phillies   6   9  30  30   0  211.0  207  26   28
# 5         R.A. Dickey          Mets  20   6  34  33   5  233.2  192  24   54
# 6        Gio Gonzalez     Nationals  21   8  32  32   2  199.1  149   9   76
# 7        Zack Greinke       Dodgers  15   5  34  34   0  212.1  200  18   54
# 8          Chris Sale     White Sox  17   8  30  29   1  192.0  167  19   51
# 9        Johnny Cueto          Reds  19   9  33  33   2  217.0  205  15   49
# 10        CC Sabathia       Yankees  15   6  28  28   2  200.0  184  22   44
# ...

# %%
merge.dtypes
# Out:
# Name      object
# Team      object
# W          int64
# L          int64
# G          int64
# GS         int64
# CG         int64
# IP       float64
# H          int64
# HR         int64
# BB         int64
# SO         int64
# R          int64
# SV         int64
# BS         int64
# BK         int64
# ER         int64
# HBP        int64
# HLD        int64
# IBB        int64
# ShO        int64
# TBF        int64
# WP         int64
# HR/9     float64
# BB/9     float64
# K/9      float64
# K/BB     float64
# K-BB%    float64
# GB%      float64
# HR/FB    float64
# LOB%     float64
# ERA      float64
# BABIP    float64
# FIP      float64
# WHIP     float64
# WPA      float64
# WAR      float64
# dtype: object

# %%
merge.to_csv('../csv/2012/2012_Merging_pitchers_stats.csv', index=None)
