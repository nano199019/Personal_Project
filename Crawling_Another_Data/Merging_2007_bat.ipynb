# %%
import pandas as pd
import numpy as np
import re

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
read_dash = pd.read_csv('../csv/2007/Merging_2007_DASH_bat.csv')
read_std = pd.read_csv('../csv/2007/Merging_2007_STD_bat.csv')
read_adv = pd.read_csv('../csv/2007/Merging_2007_ADV_bat.csv')
read_wpa = pd.read_csv('../csv/2007/Merging_2007_WPA_bat.csv')

# %%
rd = read_dash.copy()
rs = read_std.copy()
ra = read_adv.copy()
rw = read_wpa.copy()

# %%
merge1 = rd.merge(rs, how='inner')
merge2 = merge1.merge(ra, how='inner')
merge = merge2.merge(rw, how='inner')

# %%
to_list = merge.columns.tolist()

to_list = ['Name', 'Team', 'G', 'AB', 'PA', 'H', '1B', '2B', '3B', 'HR', 'R', 'RBI', 'BB', 'IBB', 'SO', 'BB%', 'K%', 'BB/K', 'BABIP', 'HBP', 'SF', 'SH', 'GDP', 'SB', 'CS', 'Def', 'ISO', 'wOBA', 'wRAA', 'AVG', 'OBP', 'SLG', 'OPS', 'WAR', 'wRC+', 'WPA']
merge = merge[to_list]

print(merge.shape)
# Out:
# (162, 36)

# %%
copy = merge.copy()

# %%
bb_list = list(copy['BB%'])
k_list = list(copy['K%'])

bb = [float(re.sub(r' %', '', x)) for x in list(bb_list)]
k = [float(re.sub(r' %', '', x)) for x in list(k_list)]

# %%
merge['BB%'] = bb
merge['K%'] = k

# %%
print(merge.shape)
merge
# Out:
# (162, 36)
#                     Name          Team    G   AB   PA    H   1B  2B  3B  HR  \
# 0         Alex Rodriguez       Yankees  158  583  708  183   98  31   0  54
# 1           David Wright          Mets  160  604  711  196  123  42   1  30
# 2        Magglio Ordonez        Tigers  157  595  679  216  134  54   0  28
# 3      Curtis Granderson        Tigers  158  612  676  185  101  38  23  23
# 4          Albert Pujols     Cardinals  158  565  679  185  114  38   1  32
# 5            Chase Utley      Phillies  132  530  613  176  101  48   5  22
# 6          Chipper Jones        Braves  134  513  600  173   98  42   4  29
# 7          Matt Holliday       Rockies  158  636  713  216  124  50   6  36
# 8        Alfonso Soriano          Cubs  135  579  617  173   93  42   5  33
# 9          Jimmy Rollins      Phillies  162  716  778  212  124  38  20  30
# 10        Grady Sizemore       Indians  162  628  748  174  111  34   5  24
# ...

# %%
merge.loc[36, 'Team'] = 'Braves'
merge.loc[69, 'Team'] = 'Indians'
merge.loc[76, 'Team'] = 'Mets'
merge.loc[116, 'Team'] = 'Phillies'
merge.loc[132, 'Team'] = 'Astros'
merge.loc[157, 'Team'] = 'Cubs'

# %%
print(merge.shape)
merge
# Out:
# (162, 36)
#                     Name          Team    G   AB   PA    H   1B  2B  3B  HR  \
# 0         Alex Rodriguez       Yankees  158  583  708  183   98  31   0  54
# 1           David Wright          Mets  160  604  711  196  123  42   1  30
# 2        Magglio Ordonez        Tigers  157  595  679  216  134  54   0  28
# 3      Curtis Granderson        Tigers  158  612  676  185  101  38  23  23
# 4          Albert Pujols     Cardinals  158  565  679  185  114  38   1  32
# 5            Chase Utley      Phillies  132  530  613  176  101  48   5  22
# 6          Chipper Jones        Braves  134  513  600  173   98  42   4  29
# 7          Matt Holliday       Rockies  158  636  713  216  124  50   6  36
# 8        Alfonso Soriano          Cubs  135  579  617  173   93  42   5  33
# 9          Jimmy Rollins      Phillies  162  716  778  212  124  38  20  30
# 10        Grady Sizemore       Indians  162  628  748  174  111  34   5  24
# ...

# %%
merge.dtypes
# Out:
# Name      object
# Team      object
# G          int64
# AB         int64
# PA         int64
# H          int64
# 1B         int64
# 2B         int64
# 3B         int64
# HR         int64
# R          int64
# RBI        int64
# BB         int64
# IBB        int64
# SO         int64
# BB%      float64
# K%       float64
# BB/K     float64
# BABIP    float64
# HBP        int64
# SF         int64
# SH         int64
# GDP        int64
# SB         int64
# CS         int64
# Def      float64
# ISO      float64
# wOBA     float64
# wRAA     float64
# AVG      float64
# OBP      float64
# SLG      float64
# OPS      float64
# WAR      float64
# wRC+       int64
# WPA      float64
# dtype: object

# %%
merge.to_csv('../csv/2007/2007_Merging_batters_stats.csv', index=None)
