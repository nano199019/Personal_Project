# %%
import pandas as pd
import numpy as np
import re

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
read_dash = pd.read_csv('../csv/2015/Merging_2015_DASH_bat.csv')
read_std = pd.read_csv('../csv/2015/Merging_2015_STD_bat.csv')
read_adv = pd.read_csv('../csv/2015/Merging_2015_ADV_bat.csv')
read_wpa = pd.read_csv('../csv/2015/Merging_2015_WPA_bat.csv')

# %%
rd = read_dash.copy()
rs = read_std.copy()
ra = read_adv.copy()
rw = read_wpa.copy()

# %%
merge1 = rd.merge(rs, how='inner')
merge2 = merge1.merge(ra, how='inner')
merge = merge2.merge(rw, how='inner')

print(merge.shape)
merge
# Out:
# (141, 53)
#                    Name          Team    G   PA  HR    R  RBI  SB     BB%  \
# 0          Bryce Harper     Nationals  153  654  42  118   99   6  19.0 %
# 1            Mike Trout        Angels  159  682  41  104   90  11  13.5 %
# 2        Josh Donaldson     Blue Jays  158  711  41  122  123   6  10.3 %
# 3            Joey Votto          Reds  158  695  29   95   80  11  20.6 %
# 4      Paul Goldschmidt  Diamondbacks  159  695  33  103  110  21  17.0 %
# 5         Manny Machado       Orioles  162  713  35  102   86  20   9.8 %
# 6       Yoenis Cespedes         - - -  159  676  35  101  105   7   4.9 %
# 7           Kris Bryant          Cubs  151  650  26   87   99  13  11.8 %
# 8          Lorenzo Cain        Royals  140  604  16  101   72  28   6.1 %
# 9          A.J. Pollock  Diamondbacks  157  673  20  111   76  39   7.9 %
# 10        Jason Heyward     Cardinals  154  610  13   79   60  23   9.2 %
# ...

# %%
to_list = merge.columns.tolist()

to_list = ['Name', 'Team', 'G', 'AB', 'PA', 'H', '1B', '2B', '3B', 'HR', 'R', 'RBI', 'BB', 'IBB', 'SO', 'BB%', 'K%', 'BB/K', 'BABIP', 'HBP', 'SF', 'SH', 'GDP', 'SB', 'CS', 'Def', 'ISO', 'wOBA', 'wRAA', 'AVG', 'OBP', 'SLG', 'OPS', 'WAR', 'wRC+', 'WPA']
merge = merge[to_list]

print(merge.shape)
merge
# Out:
# (141, 36)
#                    Name          Team    G   AB   PA    H   1B  2B  3B  HR  \
# 0          Bryce Harper     Nationals  153  521  654  172   91  38   1  42
# 1            Mike Trout        Angels  159  575  682  172   93  32   6  41
# 2        Josh Donaldson     Blue Jays  158  620  711  184  100  41   2  41
# 3            Joey Votto          Reds  158  545  695  171  107  33   2  29
# 4      Paul Goldschmidt  Diamondbacks  159  567  695  182  109  38   2  33
# 5         Manny Machado       Orioles  162  633  713  181  115  30   1  35
# 6       Yoenis Cespedes         - - -  159  633  676  184  101  42   6  35
# 7           Kris Bryant          Cubs  151  559  650  154   92  31   5  26
# 8          Lorenzo Cain        Royals  140  551  604  169  113  34   6  16
# 9          A.J. Pollock  Diamondbacks  157  609  673  192  127  39   6  20
# 10        Jason Heyward     Cardinals  154  547  610  160  110  33   4  13
# ...

# %%
copy = merge.copy()

# %%
bb_list = list(copy['BB%'])
k_list = list(copy['K%'])

bb = [float(re.sub(r' %', '', x)) for x in list(bb_list)]
k = [float(re.sub(r' %', '', x)) for x in list(k_list)]

# %%
merge['BB%'] = bb
merge['K%'] = k

merge
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                    Name          Team    G   AB   PA    H   1B  2B  3B  HR  \
# 0          Bryce Harper     Nationals  153  521  654  172   91  38   1  42
# 1            Mike Trout        Angels  159  575  682  172   93  32   6  41
# ...

# %%
merge.loc[6, 'Team'] = 'Mets'
merge.loc[76, 'Team'] = 'Rockies'
merge.loc[80, 'Team'] = 'White Sox'
merge.loc[93, 'Team'] = 'Cubs'
merge.loc[95, 'Team'] = 'Blue Jays'
merge.loc[110, 'Team'] = 'Diamondbacks'
merge.loc[111, 'Team'] = 'Reds'
merge.loc[116, 'Team'] = 'Pirates'
merge.loc[118, 'Team'] = 'Rockies'
merge.loc[120, 'Team'] = 'Orioles'
merge.loc[121, 'Team'] = 'Cardinals'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
print(merge.shape)
merge
# Out:
# (141, 36)
#                    Name          Team    G   AB   PA    H   1B  2B  3B  HR  \
# 0          Bryce Harper     Nationals  153  521  654  172   91  38   1  42
# 1            Mike Trout        Angels  159  575  682  172   93  32   6  41
# 2        Josh Donaldson     Blue Jays  158  620  711  184  100  41   2  41
# 3            Joey Votto          Reds  158  545  695  171  107  33   2  29
# 4      Paul Goldschmidt  Diamondbacks  159  567  695  182  109  38   2  33
# 5         Manny Machado       Orioles  162  633  713  181  115  30   1  35
# 6       Yoenis Cespedes          Mets  159  633  676  184  101  42   6  35
# 7           Kris Bryant          Cubs  151  559  650  154   92  31   5  26
# 8          Lorenzo Cain        Royals  140  551  604  169  113  34   6  16
# 9          A.J. Pollock  Diamondbacks  157  609  673  192  127  39   6  20
# 10        Jason Heyward     Cardinals  154  547  610  160  110  33   4  13
# ...

# %%
merge.dtypes
# Out:
# Name      object
# Team      object
# G          int64
# AB         int64
# PA         int64
# H          int64
# 1B         int64
# 2B         int64
# 3B         int64
# HR         int64
# R          int64
# RBI        int64
# BB         int64
# IBB        int64
# SO         int64
# BB%      float64
# K%       float64
# BB/K     float64
# BABIP    float64
# HBP        int64
# SF         int64
# SH         int64
# GDP        int64
# SB         int64
# CS         int64
# Def      float64
# ISO      float64
# wOBA     float64
# wRAA     float64
# AVG      float64
# OBP      float64
# SLG      float64
# OPS      float64
# WAR      float64
# wRC+       int64
# WPA      float64
# dtype: object

# %%
merge.to_csv('../csv/2015/2015_Merging_batters_stats.csv', index=None)
