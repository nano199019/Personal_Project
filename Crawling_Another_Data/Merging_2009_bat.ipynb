# %%
import pandas as pd
import numpy as np
import re

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
read_dash = pd.read_csv('../csv/2009/Merging_2009_DASH_bat.csv')
read_std = pd.read_csv('../csv/2009/Merging_2009_STD_bat.csv')
read_adv = pd.read_csv('../csv/2009/Merging_2009_ADV_bat.csv')
read_wpa = pd.read_csv('../csv/2009/Merging_2009_WPA_bat.csv')

# %%
rd = read_dash.copy()
rs = read_std.copy()
ra = read_adv.copy()
rw = read_wpa.copy()

# %%
merge1 = rd.merge(rs, how='inner')
merge2 = merge1.merge(ra, how='inner')
merge = merge2.merge(rw, how='inner')

# %%
to_list = merge.columns.tolist()

to_list = ['Name', 'Team', 'G', 'AB', 'PA', 'H', '1B', '2B', '3B', 'HR', 'R', 'RBI', 'BB', 'IBB', 'SO', 'BB%', 'K%', 'BB/K', 'BABIP', 'HBP', 'SF', 'SH', 'GDP', 'SB', 'CS', 'Def', 'ISO', 'wOBA', 'wRAA', 'AVG', 'OBP', 'SLG', 'OPS', 'WAR', 'wRC+', 'WPA']
merge = merge[to_list]

print(merge.shape)
# Out:
# (154, 36)

# %%
copy = merge.copy()

# %%
bb_list = list(copy['BB%'])
k_list = list(copy['K%'])

bb = [float(re.sub(r' %', '', x)) for x in list(bb_list)]
k = [float(re.sub(r' %', '', x)) for x in list(k_list)]

# %%
merge['BB%'] = bb
merge['K%'] = k

# %%
print(merge.shape)
merge
# Out:
# (154, 36)
#                     Name          Team    G   AB   PA    H   1B  2B  3B  HR  \
# 0            Ben Zobrist          Rays  152  501  599  149   87  28   7  27
# 1          Albert Pujols     Cardinals  160  568  700  186   93  45   1  47
# 2            Chase Utley      Phillies  156  571  687  161   98  28   4  31
# 3              Joe Mauer         Twins  138  523  606  191  132  30   1  28
# 4          Evan Longoria          Rays  157  584  671  164   87  44   0  33
# 5         Hanley Ramirez       Marlins  151  576  652  197  130  42   1  24
# 6            Derek Jeter       Yankees  153  634  716  212  166  27   1  18
# 7         Ryan Zimmerman     Nationals  157  610  694  178  105  37   3  33
# 8          Chone Figgins        Angels  158  615  729  183  141  30   7   5
# 9     Franklin Gutierrez      Mariners  153  565  629  160  117  24   1  18
# 10        Prince Fielder       Brewers  162  591  719  177   93  35   3  46
# ...

# %%
merge.loc[15, 'Team'] = 'Athletics'
merge.loc[26, 'Team'] = 'Pirates'
merge.loc[39, 'Team'] = 'Blue Jays'
merge.loc[43, 'Team'] = 'Red Sox'
merge.loc[49, 'Team'] = 'Diamondbacks'
merge.loc[63, 'Team'] = 'Braves'
merge.loc[96, 'Team'] = 'Braves'
merge.loc[109, 'Team'] = 'Cardinals'
merge.loc[116, 'Team'] = 'Marlins'
merge.loc[136, 'Team'] = 'Twins'
merge.loc[143, 'Team'] = 'Mets'
merge.loc[144, 'Team'] = 'White Sox'
merge.loc[152, 'Team'] = 'Tigers'
merge.loc[153, 'Team'] = 'Royals'

# %%
print(merge.shape)
merge
# Out:
# (154, 36)
#                     Name          Team    G   AB   PA    H   1B  2B  3B  HR  \
# 0            Ben Zobrist          Rays  152  501  599  149   87  28   7  27
# 1          Albert Pujols     Cardinals  160  568  700  186   93  45   1  47
# 2            Chase Utley      Phillies  156  571  687  161   98  28   4  31
# 3              Joe Mauer         Twins  138  523  606  191  132  30   1  28
# 4          Evan Longoria          Rays  157  584  671  164   87  44   0  33
# 5         Hanley Ramirez       Marlins  151  576  652  197  130  42   1  24
# 6            Derek Jeter       Yankees  153  634  716  212  166  27   1  18
# 7         Ryan Zimmerman     Nationals  157  610  694  178  105  37   3  33
# 8          Chone Figgins        Angels  158  615  729  183  141  30   7   5
# 9     Franklin Gutierrez      Mariners  153  565  629  160  117  24   1  18
# 10        Prince Fielder       Brewers  162  591  719  177   93  35   3  46
# ...

# %%
merge.dtypes
# Out:
# Name      object
# Team      object
# G          int64
# AB         int64
# PA         int64
# H          int64
# 1B         int64
# 2B         int64
# 3B         int64
# HR         int64
# R          int64
# RBI        int64
# BB         int64
# IBB        int64
# SO         int64
# BB%      float64
# K%       float64
# BB/K     float64
# BABIP    float64
# HBP        int64
# SF         int64
# SH         int64
# GDP        int64
# SB         int64
# CS         int64
# Def      float64
# ISO      float64
# wOBA     float64
# wRAA     float64
# AVG      float64
# OBP      float64
# SLG      float64
# OPS      float64
# WAR      float64
# wRC+       int64
# WPA      float64
# dtype: object

# %%
merge.to_csv('../csv/2009/2009_Merging_batters_stats.csv', index=None)
