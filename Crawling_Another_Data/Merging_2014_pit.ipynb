# %%
import pandas as pd
import numpy as np
import re

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
read_dash = pd.read_csv('../csv/2014/Merging_2014_DASH_pitcher.csv')
read_std = pd.read_csv('../csv/2014/Merging_2014_STD_pitcher.csv')
read_adv = pd.read_csv('../csv/2014/Merging_2014_ADV_pitcher.csv')
read_wpa = pd.read_csv('../csv/2014/Merging_2014_WPA_pitcher.csv')

# %%
rd = read_dash.copy()
rs = read_std.copy()
ra = read_adv.copy()
rw = read_wpa.copy()

# %%
merge1 = rd.merge(rs, how='inner')
merge2 = merge1.merge(ra, how='inner')
merge = merge2.merge(rw, how='inner')

print(merge.shape)
merge
# Out:
# (88, 60)
#                  Name          Team   W   L  SV   G  GS     IP    K/9  BB/9  \
# 0     Clayton Kershaw       Dodgers  21   3   0  27  27  198.1  10.85  1.41
# 1        Corey Kluber       Indians  18   9   0  34  34  235.2  10.27  1.95
# 2     Felix Hernandez      Mariners  15   6   0  34  34  236.0   9.46  1.75
# 3         David Price         - - -  15  12   0  34  34  248.1   9.82  1.38
# 4         Phil Hughes         Twins  16  10   0  32  32  209.2   7.98  0.69
# 5          Jon Lester         - - -  16  11   0  32  32  219.2   9.01  1.97
# 6   Jordan Zimmermann     Nationals  14   5   0  32  32  199.2   8.20  1.31
# 7        Max Scherzer        Tigers  18   5   0  33  33  220.1  10.29  2.57
# 8          Chris Sale     White Sox  12   4   0  26  26  174.0  10.76  2.02
# 9       Jose Quintana     White Sox   9  11   0  32  32  200.1   8.00  2.34
# 10    Adam Wainwright     Cardinals  20   9   0  32  32  227.0   7.10  1.98
# ...

# %%
to_list = merge.columns.tolist()

to_list = ['Name', 'Team', 'W', 'L', 'G', 'GS', 'CG', 'IP', 'H', 'HR', 'BB', 'SO', 'R', 'SV', 'BS', 'BK', 'ER', 'HBP', 'HLD', 'IBB', 'ShO', 'TBF', 'WP', 'HR/9', 'BB/9', 'K/9', 'K/BB', 'K-BB%', 'GB%', 'HR/FB', 'LOB%', 'ERA', 'BABIP', 'FIP', 'WHIP', 'WPA', 'WAR']
merge = merge[to_list]

print(merge.shape)
merge
# Out:
# (88, 37)
#                  Name          Team   W   L   G  GS  CG     IP    H  HR  BB  \
# 0     Clayton Kershaw       Dodgers  21   3  27  27   6  198.1  139   9  31
# 1        Corey Kluber       Indians  18   9  34  34   3  235.2  207  14  51
# 2     Felix Hernandez      Mariners  15   6  34  34   0  236.0  170  16  46
# 3         David Price         - - -  15  12  34  34   3  248.1  230  25  38
# 4         Phil Hughes         Twins  16  10  32  32   1  209.2  221  16  16
# 5          Jon Lester         - - -  16  11  32  32   1  219.2  194  16  48
# 6   Jordan Zimmermann     Nationals  14   5  32  32   3  199.2  185  13  29
# 7        Max Scherzer        Tigers  18   5  33  33   1  220.1  196  18  63
# 8          Chris Sale     White Sox  12   4  26  26   2  174.0  129  13  39
# 9       Jose Quintana     White Sox   9  11  32  32   0  200.1  197  10  52
# 10    Adam Wainwright     Cardinals  20   9  32  32   5  227.0  184  10  50
# ...

# %%
copy = merge.copy()

# %%
k_bb_list = merge['K-BB%']
gb_list = merge['GB%']
hr_fb_list = merge['HR/FB']
lob_list = merge['LOB%']

# %%
k_bb = [float(re.sub(r' %', '', x)) for x in list(k_bb_list)]
gb = [float(re.sub(r' %', '', x)) for x in list(gb_list)]
hr_fb = [float(re.sub(r' %', '', x)) for x in list(hr_fb_list)]
lob = [float(re.sub(r' %', '', x)) for x in list(lob_list)]

# %%
merge['K-BB%'] = k_bb
merge['GB%'] = gb
merge['HR/FB'] = hr_fb
merge['LOB%'] = lob
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
print(merge.shape)
merge
# Out:
# (88, 37)
#                  Name          Team   W   L   G  GS  CG     IP    H  HR  BB  \
# 0     Clayton Kershaw       Dodgers  21   3  27  27   6  198.1  139   9  31
# 1        Corey Kluber       Indians  18   9  34  34   3  235.2  207  14  51
# 2     Felix Hernandez      Mariners  15   6  34  34   0  236.0  170  16  46
# 3         David Price         - - -  15  12  34  34   3  248.1  230  25  38
# 4         Phil Hughes         Twins  16  10  32  32   1  209.2  221  16  16
# 5          Jon Lester         - - -  16  11  32  32   1  219.2  194  16  48
# 6   Jordan Zimmermann     Nationals  14   5  32  32   3  199.2  185  13  29
# 7        Max Scherzer        Tigers  18   5  33  33   1  220.1  196  18  63
# 8          Chris Sale     White Sox  12   4  26  26   2  174.0  129  13  39
# 9       Jose Quintana     White Sox   9  11  32  32   0  200.1  197  10  52
# 10    Adam Wainwright     Cardinals  20   9  32  32   5  227.0  184  10  50
# ...

# %%
merge.loc[3, 'Team'] = 'Tigers'
merge.loc[5, 'Team'] = 'Athletics'
merge.loc[16, 'Team'] = 'Athletics'
merge.loc[32, 'Team'] = 'Yankees'
merge.loc[42, 'Team'] = 'Cardinals'
merge.loc[56, 'Team'] = 'Marlins'
merge.loc[61, 'Team'] = 'Athletics'
merge.loc[63, 'Team'] = 'Giants'
merge.loc[84, 'Team'] = 'Rangers'
merge.loc[87, 'Team'] = 'Dodgers'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
print(merge.shape)
merge
# Out:
# (88, 37)
#                  Name          Team   W   L   G  GS  CG     IP    H  HR  BB  \
# 0     Clayton Kershaw       Dodgers  21   3  27  27   6  198.1  139   9  31
# 1        Corey Kluber       Indians  18   9  34  34   3  235.2  207  14  51
# 2     Felix Hernandez      Mariners  15   6  34  34   0  236.0  170  16  46
# 3         David Price        Tigers  15  12  34  34   3  248.1  230  25  38
# 4         Phil Hughes         Twins  16  10  32  32   1  209.2  221  16  16
# 5          Jon Lester     Athletics  16  11  32  32   1  219.2  194  16  48
# 6   Jordan Zimmermann     Nationals  14   5  32  32   3  199.2  185  13  29
# 7        Max Scherzer        Tigers  18   5  33  33   1  220.1  196  18  63
# 8          Chris Sale     White Sox  12   4  26  26   2  174.0  129  13  39
# 9       Jose Quintana     White Sox   9  11  32  32   0  200.1  197  10  52
# 10    Adam Wainwright     Cardinals  20   9  32  32   5  227.0  184  10  50
# ...

# %%
merge.dtypes
# Out:
# Name      object
# Team      object
# W          int64
# L          int64
# G          int64
# GS         int64
# CG         int64
# IP       float64
# H          int64
# HR         int64
# BB         int64
# SO         int64
# R          int64
# SV         int64
# BS         int64
# BK         int64
# ER         int64
# HBP        int64
# HLD        int64
# IBB        int64
# ShO        int64
# TBF        int64
# WP         int64
# HR/9     float64
# BB/9     float64
# K/9      float64
# K/BB     float64
# K-BB%    float64
# GB%      float64
# HR/FB    float64
# LOB%     float64
# ERA      float64
# BABIP    float64
# FIP      float64
# WHIP     float64
# WPA      float64
# WAR      float64
# dtype: object

# %%
merge.to_csv('../csv/2014/2014_Merging_pitchers_stats.csv', index=None)
